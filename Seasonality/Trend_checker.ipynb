# %%
import pandas as pd
import numpy as np

# %%
def find_dynamic_range_bound_periods(df, threshold=1.5):
    range_bound_periods = []
    start_idx = 0

    while start_idx < len(df):
        max_high = df['High'].iloc[start_idx]
        min_low = df['Low'].iloc[start_idx]
        end_idx = start_idx

        # Expand the period as long as it stays within the threshold
        while end_idx < len(df):
            max_high = max(max_high, df['High'].iloc[end_idx])
            min_low = min(min_low, df['Low'].iloc[end_idx])
            
            # If price range exceeds threshold, stop expanding
            if (max_high - min_low) > threshold:
                break
            
            end_idx += 1

        # If a range-bound period of at least 2 days is found, store it
        if end_idx - start_idx > 1:
            range_bound_periods.append({
                'Start_Date': df['Date'].iloc[start_idx],
                'End_Date': df['Date'].iloc[end_idx - 1],
                'Price_Range': f"{min_low} to {max_high}",
                'Days': end_idx - start_idx
            })

        # Move to the next period
        start_idx = end_idx

    return pd.DataFrame(range_bound_periods)

# %%
df = pd.read_csv('/workspaces/Futures-First/Prediction/data/Corn/ZC Dec-Mar/2024.csv')
df
# Out:
#            Date   Open   High    Low  Close
# 0    2023-09-08 -10.25 -10.25 -10.75 -10.50
# 1    2023-09-11 -10.75 -10.25 -10.75 -10.25
# 2    2023-09-12 -10.25 -10.25 -10.75 -10.75
# 3    2023-09-13 -10.50 -10.25 -10.75 -10.25
# 4    2023-09-14 -10.25 -10.00 -10.50 -10.25
# ..          ...    ...    ...    ...    ...
# 251  2024-09-09 -18.25 -18.25 -19.00 -19.00
# 252  2024-09-10 -18.75 -18.50 -19.00 -19.00
# 253  2024-09-11 -19.00 -18.50 -19.25 -18.75
# 254  2024-09-12 -18.75 -18.25 -19.00 -18.50
# 255  2024-09-13 -18.25 -17.50 -18.50 -17.75
#
# [256 rows x 5 columns]

# %%
range_bound_periods = find_dynamic_range_bound_periods(df, threshold=1.5)

# Show the result
print("Range-bound periods:")
print(range_bound_periods)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 range_bound_periods = find_dynamic_range_bound_periods(df, threshold=1.5)
#       3 # Show the result
#       4 print("Range-bound periods:")
#
# Cell In[8], line 6, in find_dynamic_range_bound_periods(df, threshold)
#       3 start_idx = 0
#       5 while start_idx < len(df):
# ----> 6     max_high = df['High'].iloc[start_idx]
#       7     min_low = df['Low'].iloc[start_idx]
#       8     end_idx = start_idx
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# ...

# %%
from hurst import compute_Hc

Price = df["Close"]
if len(df) > 100:
    H, c, val = compute_Hc(Price)
print("Hurst exponent = {:.4f}".format(H))
# Out:
# Hurst exponent = 0.4750
