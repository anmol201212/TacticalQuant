# %%
import warnings
warnings.filterwarnings("ignore")

# %%
# Automatic check in folder

import pandas as pd
import numpy as np
import os
from itertools import combinations

def optimize_z_ratio(df):
    # Initialize tracking variables
    best_z = None
    lowest_variance = float('inf')
    lowest_standard_deviation = float('inf')
    
    # Iterate through potential z values with decimal precision
    # Using a range from 0 to 10 with 0.1 increments
    z_values = np.arange(0, 10.1, 0.1)
    
    results = []
    
    for z in z_values:
        # Calculate Z column
        df['Z'] = df['X'] - (z * df['Y'])
        
        # Calculate variance and standard deviation of Z
        z_variance = df['Z'].var()
        z_std = df['Z'].std()
        
        # Track results
        results.append({
            'z': z,
            'variance': z_variance,
            'standard_deviation': z_std
        })
        
        # Update best z if current z has lower variance
        if z_variance < lowest_variance:
            lowest_variance = z_variance
            best_z = z
            lowest_standard_deviation = z_std
    
    # Convert results to DataFrame for easy analysis
    results_df = pd.DataFrame(results)
    
    # Return optimization results
    return best_z

def process_files_in_directory(directory):
    # List all CSV files in the directory
    files = [f for f in os.listdir(directory) if f.endswith('.csv')]
    
    # Initialize a list to store results for each pair
    results_list = []
    
    # Iterate through all pairs of files
    for file1, file2 in combinations(files, 2):
        df1 = pd.read_csv(os.path.join(directory, file1))
        df2 = pd.read_csv(os.path.join(directory, file2))

        df1 = df1.iloc[:, 1::2]
        df2 = df2.iloc[:, 1::2]

        optimization_results = []

        for i in range(df1.columns.size):
            df3 = pd.DataFrame()
            df3['X'] = pd.to_numeric(df1.iloc[:, i], errors='coerce')
            df3['Y'] = pd.to_numeric(df2.iloc[:, i], errors='coerce')

            # Remove rows with NaN values
            df3 = df3.dropna()
            df3 = df3[-250:]
            df3 = df3[:230]

            # Perform optimization
            optimization_results.append(optimize_z_ratio(df3))

        # Convert results to a Series for easy analysis
        optimization_results_series = pd.Series(optimization_results)

        # Calculate mean and median
        mean_z = optimization_results_series.mean()
        median_z = optimization_results_series.median()

        # Append results to the list
        results_list.append({
            'Contract 1': file1,
            'Contract 2': file2,
            'Mean': mean_z,
            'Median': median_z
        })

    # Convert the list of results to a DataFrame
    results_df = pd.DataFrame(results_list)
    
    return results_df

# Specify the directory containing the CSV files
directory = '/workspaces/Futures-First/BackTest/data/ZW Contracts'

# Process all files in the directory and get the results DataFrame
results_df = process_files_in_directory(directory)

# Display the results DataFrame
print(results_df)
# Out:
#              Contract 1          Contract 2   Mean  Median
# 0    ZW May25-Dec25.csv  ZW Sep25-Mar26.csv  1.800    1.50
# 1    ZW May25-Dec25.csv  ZW Dec25-May26.csv  1.095    1.20
# 2    ZW May25-Dec25.csv  ZW Mar26-Sep26.csv  0.350    0.20
# 3    ZW May25-Dec25.csv  ZW May25-Jul25.csv  1.895    1.80
# 4    ZW May25-Dec25.csv  ZW Sep25-May26.csv  0.865    0.95
# ..                  ...                 ...    ...     ...
# 185  ZW Jul25-Sep25.csv  ZW May26-Jul26.csv  0.170    0.10
# 186  ZW Jul25-Sep25.csv  ZW Sep25-Dec25.csv  0.695    0.70
# 187  ZW Dec25-Mar26.csv  ZW May26-Jul26.csv  0.235    0.20
# 188  ZW Dec25-Mar26.csv  ZW Sep25-Dec25.csv  0.845    0.80
# 189  ZW May26-Jul26.csv  ZW Sep25-Dec25.csv  1.315    0.80
#
# [190 rows x 4 columns]

# %%
results_df.to_csv('/workspaces/Futures-First/BackTest/data/RatioResult/Wheat.csv',index=False)

# %%
import pandas as pd
import numpy as np
import os
from itertools import combinations
from datetime import datetime

# Month names for display
MONTH_NAMES = ['January', 'February', 'March', 'April', 'May', 'June',
               'July', 'August', 'September', 'October', 'November', 'December']

def optimize_z_ratio_monthly(df):
    best_z = 0
    best_sharpe = -np.inf
    
    z_values = np.arange(0, 10.1, 0.1)
    
    for z in z_values:
        df['Spread'] = df['Value_X'] - z * df['Value_Y']
        returns = df['Spread'].pct_change().dropna()
        
        # Skip if returns contain NaN or inf
        if len(returns) < 2 or returns.isnull().any() or np.isinf(returns).any():
            continue
        
        sharpe = returns.mean() / returns.std()
        if sharpe > best_sharpe:
            best_sharpe = sharpe
            best_z = z
            
    return best_z, best_sharpe

def process_contract_file(file_path):
    """Convert wide-format contract data to long format"""
    df = pd.read_csv(file_path)
    melted = pd.DataFrame()

    for i in range(0, len(df.columns), 2):
        if i+1 >= len(df.columns):
            break
            
        date_col = df.columns[i]
        value_col = df.columns[i+1]
        year = value_col
        
        temp_df = df[[date_col, value_col]].copy()
        temp_df.columns = ['Date', 'Value']
        temp_df['ContractYear'] = year
        melted = pd.concat([melted, temp_df])

    melted['Date'] = pd.to_datetime(melted['Date'], errors='coerce')
    melted['Value'] = pd.to_numeric(melted['Value'], errors='coerce')  # Ensure numeric values
    melted = melted.dropna(subset=['Date', 'Value'])  # Drop rows with invalid dates or values
    melted = melted.replace([np.inf, -np.inf], np.nan).dropna()  # Handle infinite values
    return melted


def process_files_monthly(directory):
    results = []
    
    for file1, file2 in combinations(os.listdir(directory), 2):
        if not (file1.endswith('.csv') and file2.endswith('.csv')):
            continue
            
        # Load and merge data
        df1 = process_contract_file(os.path.join(directory, file1))
        df2 = process_contract_file(os.path.join(directory, file2))
        
        merged = pd.merge(df1, df2, on='Date', suffixes=('_X', '_Y'))
        if merged.empty:
            continue
            
        merged['Month'] = merged['Date'].dt.month
        
        monthly_sharpe = {}

        # Calculate monthly Sharpe ratios
        for month, group in merged.groupby('Month'):
            group = group.sort_values('Date')
            if len(group) < 5:  # Minimum data threshold
                continue
                
            _, sharpe = optimize_z_ratio_monthly(group)
            if not np.isnan(sharpe) and not np.isinf(sharpe):  # Skip invalid Sharpe ratios
                monthly_sharpe[month] = sharpe

        if not monthly_sharpe:
            continue

        # Prepare result row
        max_sharpe = max(monthly_sharpe.values())
        best_month_num = max(monthly_sharpe, key=monthly_sharpe.get)
        
        row = {
            'Contract1': file1[:-4],
            'Contract2': file2[:-4],
            'Best': max_sharpe,
            'Average': np.mean(list(monthly_sharpe.values())),
            'Best Month': MONTH_NAMES[best_month_num - 1]
        }

        # Add monthly values
        for month_num in range(1, 13):
            month_name = MONTH_NAMES[month_num - 1]
            row[month_name] = monthly_sharpe.get(month_num, np.nan)

        results.append(row)
    
    return pd.DataFrame(results)


# Example usage
if __name__ == "__main__":
    results = process_files_monthly('/workspaces/Futures-First/BackTest/data/ZL Contracts')
    print("Monthly Optimization Results:")
    print(results.to_string(index=False))
# Out:
# Monthly Optimization Results:
#      Contract1      Contract2     Best  Average Best Month  January  February    March    April      May     June     July   August  September  October  November  December
# ZL Jan26-Jul26 ZL May25-Oct25 0.065111 0.065111     August      NaN       NaN      NaN      NaN      NaN      NaN      NaN 0.065111        NaN      NaN       NaN       NaN
# ZL Jan26-Jul26 ZL Mar25-Aug25 0.083508 0.074592       June      NaN       NaN      NaN      NaN      NaN 0.083508 0.077328 0.062942        NaN      NaN       NaN       NaN
# ZL Jan26-Jul26 ZL Mar25-Jul25 0.095101 0.082167      April      NaN       NaN      NaN 0.095101      NaN      NaN 0.069233      NaN        NaN      NaN       NaN       NaN
# ZL Jan26-Jul26 ZL Aug25-Oct25 0.046196 0.046196     August      NaN       NaN      NaN      NaN      NaN      NaN      NaN 0.046196        NaN      NaN       NaN       NaN
# ZL Jan26-Jul26 ZL Aug25-Jan26 0.059044 0.051772    October      NaN       NaN      NaN      NaN      NaN      NaN      NaN      NaN   0.044500 0.059044       NaN       NaN
# ZL Jan26-Jul26 ZL Mar25-Sep25 0.110889 0.079925        May      NaN       NaN      NaN      NaN 0.110889 0.069226 0.076290 0.063294        NaN      NaN       NaN       NaN
# ZL Jan26-Jul26 ZL Jul25-Sep25 0.062216 0.062216     August      NaN       NaN      NaN      NaN      NaN      NaN      NaN 0.062216        NaN      NaN       NaN       NaN
# ZL Jan26-Jul26 ZL Sep25-Jan26 0.085254 0.075582   November      NaN       NaN      NaN      NaN      NaN      NaN      NaN      NaN        NaN 0.065910  0.085254       NaN
# ZL Jan26-Jul26 ZL May25-Aug25 0.102627 0.102627       July      NaN       NaN      NaN      NaN      NaN      NaN 0.102627      NaN        NaN      NaN       NaN       NaN
# ZL Jan26-Jul26 ZL May25-Sep25 0.091522 0.067886       July      NaN       NaN      NaN      NaN 0.041298 0.056339 0.091522 0.082385        NaN      NaN       NaN       NaN
# ZL Jan26-Jul26 ZL Mar25-May25 0.115990 0.088161     August      NaN       NaN      NaN 0.061753      NaN      NaN 0.086739 0.115990        NaN      NaN       NaN       NaN
# ZL Jan26-Jul26 ZL May25-Jul25 0.114397 0.112160       July      NaN       NaN      NaN      NaN      NaN 0.110353 0.114397 0.111732        NaN      NaN       NaN       NaN
# ZL Jan26-Jul26 ZL Sep25-Mar26 0.098679 0.078068   November      NaN       NaN      NaN      NaN      NaN      NaN      NaN      NaN        NaN 0.057457  0.098679       NaN
# ZL Jan26-May26 ZL Jul25-Dec25 0.052523 0.052523       July      NaN       NaN      NaN      NaN      NaN      NaN 0.052523      NaN        NaN      NaN       NaN       NaN
# ZL Jan26-May26 ZL Jul25-Oct25 0.052523 0.052523       July      NaN       NaN      NaN      NaN      NaN      NaN 0.052523      NaN        NaN      NaN       NaN       NaN
# ZL Jan26-May26 ZL May25-Oct25 0.071819 0.051131     August      NaN       NaN      NaN      NaN 0.030443      NaN      NaN 0.071819        NaN      NaN       NaN       NaN
# ZL Jan26-May26 ZL Mar25-Aug25 0.067466 0.058761      March      NaN       NaN 0.067466      NaN      NaN 0.063092 0.049052 0.055432        NaN      NaN       NaN       NaN
# ZL Jan26-May26 ZL Sep25-Oct25 0.052959 0.052959      April      NaN       NaN      NaN 0.052959      NaN      NaN      NaN      NaN        NaN      NaN       NaN       NaN
# ZL Jan26-May26 ZL Mar25-Jul25 0.105347 0.097682      April      NaN       NaN      NaN 0.105347      NaN      NaN 0.090016      NaN        NaN      NaN       NaN       NaN
# ZL Jan26-May26 ZL Aug25-Jan26 0.071965 0.055702    October      NaN       NaN      NaN      NaN 0.036937      NaN      NaN      NaN   0.058203 0.071965       NaN       NaN
# ZL Jan26-May26 ZL Mar25-Sep25 0.078815 0.067045       July      NaN       NaN      NaN      NaN 0.069568 0.065207 0.078815 0.054592        NaN      NaN       NaN       NaN
# ZL Jan26-May26 ZL Jul25-Sep25 0.036786 0.036786       June      NaN       NaN      NaN      NaN      NaN 0.036786      NaN      NaN        NaN      NaN       NaN       NaN
# ZL Jan26-May26 ZL Aug25-Sep25 0.044857 0.044857        May      NaN       NaN      NaN      NaN 0.044857      NaN      NaN      NaN        NaN      NaN       NaN       NaN
# ZL Jan26-May26 ZL Aug25-Dec25 0.042067 0.042067        May      NaN       NaN      NaN      NaN 0.042067      NaN      NaN      NaN        NaN      NaN       NaN       NaN
# ZL Jan26-May26 ZL Sep25-Jan26 0.089669 0.086390   November      NaN       NaN      NaN      NaN      NaN      NaN      NaN      NaN        NaN 0.083111  0.089669       NaN
# ZL Jan26-May26 ZL May25-Aug25 0.054140 0.054140       July      NaN       NaN      NaN      NaN      NaN      NaN 0.054140      NaN        NaN      NaN       NaN       NaN
# ZL Jan26-May26 ZL May25-Sep25 0.111852 0.080245       July      NaN       NaN      NaN      NaN 0.055877 0.058268 0.111852 0.094984        NaN      NaN       NaN       NaN
# ZL Jan26-May26 ZL Mar25-May25 0.143873 0.098068     August      NaN       NaN      NaN 0.084188      NaN      NaN 0.066143 0.143873        NaN      NaN       NaN       NaN
# ZL Jan26-May26 ZL May25-Jul25 0.108425 0.098271       June      NaN       NaN      NaN      NaN      NaN 0.108425 0.099422 0.086966        NaN      NaN       NaN       NaN
# ZL Jan26-May26 ZL Sep25-Mar26 0.073017 0.072347    October      NaN       NaN      NaN      NaN      NaN      NaN      NaN      NaN        NaN 0.073017  0.071676       NaN
# ZL Jul25-Dec25 ZL Oct25-Mar26 0.090842 0.071266     August      NaN       NaN      NaN      NaN 0.051691      NaN      NaN 0.090842        NaN      NaN       NaN       NaN
# ZL Jul25-Dec25 ZL May25-Oct25 0.102707 0.067657     August      NaN       NaN      NaN      NaN 0.046755 0.056275 0.064891 0.102707        NaN      NaN       NaN       NaN
# ZL Jul25-Dec25 ZL Mar25-Aug25 0.124575 0.075803     August      NaN       NaN 0.072203 0.056068 0.066890 0.066236 0.068843 0.124575        NaN      NaN       NaN       NaN
# ZL Jul25-Dec25 ZL Mar25-Jul25 0.109867 0.085912     August      NaN       NaN 0.051843 0.075997 0.075058 0.094598 0.108108 0.109867        NaN      NaN       NaN       NaN
# ZL Jul25-Dec25 ZL Aug25-Jan26 0.089904 0.065809  September      NaN       NaN      NaN 0.043792      NaN      NaN 0.063733      NaN   0.089904      NaN       NaN       NaN
# ZL Jul25-Dec25 ZL Mar25-Sep25 0.115442 0.078801     August      NaN       NaN 0.073785 0.068503 0.072883 0.069143 0.073054 0.115442        NaN      NaN       NaN       NaN
# ZL Jul25-Dec25 ZL Oct25-Jan26 0.173519 0.125495     August      NaN       NaN      NaN      NaN      NaN      NaN 0.077471 0.173519        NaN      NaN       NaN       NaN
# ZL Jul25-Dec25 ZL Oct25-May26 0.145429 0.086010     August      NaN       NaN      NaN 0.045237 0.052383      NaN 0.100990 0.145429        NaN      NaN       NaN       NaN
# ZL Jul25-Dec25 ZL Dec25-May26 0.043830 0.041194        May      NaN       NaN      NaN 0.037054 0.043830      NaN 0.042698      NaN        NaN      NaN       NaN       NaN
# ZL Jul25-Dec25 ZL Aug25-Dec25 0.065324 0.065324       July      NaN       NaN      NaN      NaN      NaN      NaN 0.065324      NaN        NaN      NaN       NaN       NaN
# ZL Jul25-Dec25 ZL Sep25-Jan26 0.078482 0.057202   November      NaN       NaN      NaN 0.034733      NaN      NaN 0.055780      NaN   0.059812      NaN  0.078482       NaN
# ZL Jul25-Dec25 ZL May25-Aug25 0.140633 0.074270     August      NaN       NaN      NaN      NaN 0.053655 0.048398 0.054393 0.140633        NaN      NaN       NaN       NaN
# ZL Jul25-Dec25 ZL May25-Sep25 0.083487 0.064672     August      NaN       NaN      NaN      NaN 0.062836 0.056480 0.055886 0.083487        NaN      NaN       NaN       NaN
# ZL Jul25-Dec25 ZL Jan26-Aug26 0.051828 0.044743       July      NaN       NaN      NaN 0.047439 0.034962      NaN 0.051828      NaN        NaN      NaN       NaN       NaN
# ZL Jul25-Dec25 ZL Mar25-May25 0.117928 0.076620     August      NaN       NaN      NaN 0.065860 0.075582 0.062783 0.060948 0.117928        NaN      NaN       NaN       NaN
# ZL Jul25-Dec25 ZL May25-Jul25 0.117392 0.086913     August      NaN       NaN      NaN      NaN 0.052310 0.080297 0.097652 0.117392        NaN      NaN       NaN       NaN
# ZL Jul25-Dec25 ZL Sep25-Dec25 0.046290 0.046290       July      NaN       NaN      NaN      NaN      NaN      NaN 0.046290      NaN        NaN      NaN       NaN       NaN
# ZL Jul25-Dec25 ZL Sep25-Mar26 0.068443 0.052554       July      NaN       NaN      NaN 0.042707 0.041683      NaN 0.068443      NaN   0.057382      NaN       NaN       NaN
# ZL Jul25-Oct25 ZL Oct25-Mar26 0.090842 0.071266     August      NaN       NaN      NaN      NaN 0.051691      NaN      NaN 0.090842        NaN      NaN       NaN       NaN
# ZL Jul25-Oct25 ZL May25-Oct25 0.102707 0.067657     August      NaN       NaN      NaN      NaN 0.046755 0.056275 0.064891 0.102707        NaN      NaN       NaN       NaN
# ZL Jul25-Oct25 ZL Mar25-Aug25 0.124575 0.075803     August      NaN       NaN 0.072203 0.056068 0.066890 0.066236 0.068843 0.124575        NaN      NaN       NaN       NaN
# ZL Jul25-Oct25 ZL Mar25-Jul25 0.109867 0.085912     August      NaN       NaN 0.051843 0.075997 0.075058 0.094598 0.108108 0.109867        NaN      NaN       NaN       NaN
# ZL Jul25-Oct25 ZL Aug25-Jan26 0.089904 0.065809  September      NaN       NaN      NaN 0.043792      NaN      NaN 0.063733      NaN   0.089904      NaN       NaN       NaN
# ZL Jul25-Oct25 ZL Mar25-Sep25 0.115442 0.078801     August      NaN       NaN 0.073785 0.068503 0.072883 0.069143 0.073054 0.115442        NaN      NaN       NaN       NaN
# ZL Jul25-Oct25 ZL Oct25-Jan26 0.173519 0.125495     August      NaN       NaN      NaN      NaN      NaN      NaN 0.077471 0.173519        NaN      NaN       NaN       NaN
# ZL Jul25-Oct25 ZL Oct25-May26 0.145429 0.086010     August      NaN       NaN      NaN 0.045237 0.052383      NaN 0.100990 0.145429        NaN      NaN       NaN       NaN
# ZL Jul25-Oct25 ZL Dec25-May26 0.043830 0.041194        May      NaN       NaN      NaN 0.037054 0.043830      NaN 0.042698      NaN        NaN      NaN       NaN       NaN
# ZL Jul25-Oct25 ZL Aug25-Dec25 0.065324 0.065324       July      NaN       NaN      NaN      NaN      NaN      NaN 0.065324      NaN        NaN      NaN       NaN       NaN
# ZL Jul25-Oct25 ZL Sep25-Jan26 0.078482 0.057202   November      NaN       NaN      NaN 0.034733      NaN      NaN 0.055780      NaN   0.059812      NaN  0.078482       NaN
# ZL Jul25-Oct25 ZL May25-Aug25 0.140633 0.074270     August      NaN       NaN      NaN      NaN 0.053655 0.048398 0.054393 0.140633        NaN      NaN       NaN       NaN
# ZL Jul25-Oct25 ZL May25-Sep25 0.083487 0.064672     August      NaN       NaN      NaN      NaN 0.062836 0.056480 0.055886 0.083487        NaN      NaN       NaN       NaN
# ZL Jul25-Oct25 ZL Jan26-Aug26 0.051828 0.044743       July      NaN       NaN      NaN 0.047439 0.034962      NaN 0.051828      NaN        NaN      NaN       NaN       NaN
# ZL Jul25-Oct25 ZL Mar25-May25 0.117928 0.076620     August      NaN       NaN      NaN 0.065860 0.075582 0.062783 0.060948 0.117928        NaN      NaN       NaN       NaN
# ZL Jul25-Oct25 ZL May25-Jul25 0.117392 0.086913     August      NaN       NaN      NaN      NaN 0.052310 0.080297 0.097652 0.117392        NaN      NaN       NaN       NaN
# ZL Jul25-Oct25 ZL Sep25-Dec25 0.046290 0.046290       July      NaN       NaN      NaN      NaN      NaN      NaN 0.046290      NaN        NaN      NaN       NaN       NaN
# ZL Jul25-Oct25 ZL Sep25-Mar26 0.068443 0.052554       July      NaN       NaN      NaN 0.042707 0.041683      NaN 0.068443      NaN   0.057382      NaN       NaN       NaN
# ZL Oct25-Mar26 ZL May25-Oct25 0.081774 0.058442     August      NaN       NaN      NaN 0.049779 0.042467 0.062573 0.055617 0.081774        NaN      NaN       NaN       NaN
# ZL Oct25-Mar26 ZL Mar25-Aug25 0.077271 0.065258    January 0.077271  0.061934 0.051826 0.076895 0.065109      NaN      NaN      NaN        NaN      NaN       NaN  0.058510
# ZL Oct25-Mar26 ZL Sep25-Oct25 0.052802 0.044842       June      NaN       NaN      NaN 0.048079 0.033646 0.052802      NaN      NaN        NaN      NaN       NaN       NaN
# ZL Oct25-Mar26 ZL Mar25-Jul25 0.099289 0.074557      March      NaN  0.070775 0.099289 0.063717 0.066889 0.063237 0.068629 0.089361        NaN      NaN       NaN       NaN
# ZL Oct25-Mar26 ZL Aug25-Oct25 0.046604 0.041466     August      NaN       NaN      NaN      NaN 0.036327      NaN      NaN 0.046604        NaN      NaN       NaN       NaN
# ZL Oct25-Mar26 ZL Aug25-Jan26 0.094513 0.068819   November      NaN       NaN      NaN      NaN 0.029297      NaN      NaN 0.074364   0.091186 0.054738  0.094513       NaN
# ZL Oct25-Mar26 ZL Mar25-Sep25 0.153571 0.076130       July 0.060518  0.054171 0.054776 0.059742 0.090260 0.063114 0.153571 0.066346        NaN      NaN       NaN  0.082671
# ZL Oct25-Mar26 ZL Jul25-Sep25 0.062546 0.055333       June      NaN       NaN      NaN      NaN 0.046459 0.062546 0.052280 0.060046        NaN      NaN       NaN       NaN
# ZL Oct25-Mar26 ZL Aug25-Sep25 0.034393 0.034393     August      NaN       NaN      NaN      NaN      NaN      NaN      NaN 0.034393        NaN      NaN       NaN       NaN
# ZL Oct25-Mar26 ZL Aug25-Dec25 0.035906 0.028689     August      NaN       NaN      NaN      NaN 0.021472      NaN      NaN 0.035906        NaN      NaN       NaN       NaN
# ZL Oct25-Mar26 ZL Sep25-Jan26 0.152972 0.063659    October      NaN       NaN      NaN      NaN 0.034117 0.034325      NaN 0.042824   0.032131 0.152972  0.085583       NaN
# ZL Oct25-Mar26 ZL May25-Aug25 0.073306 0.065979       June      NaN       NaN      NaN      NaN 0.061565 0.073306      NaN 0.063065        NaN      NaN       NaN       NaN
# ZL Oct25-Mar26 ZL May25-Sep25 0.116902 0.092528       June      NaN       NaN      NaN      NaN 0.043736 0.116902 0.100166 0.109307        NaN      NaN       NaN       NaN
# ZL Oct25-Mar26 ZL Mar25-May25 0.092775 0.067399     August      NaN  0.048319 0.073977 0.069298 0.070190 0.055344 0.061887 0.092775        NaN      NaN       NaN       NaN
# ZL Oct25-Mar26 ZL May25-Jul25 0.106529 0.071970     August      NaN  0.068086 0.064066 0.053347 0.079385 0.060916 0.071464 0.106529        NaN      NaN       NaN       NaN
# ZL Oct25-Mar26 ZL Sep25-Dec25 0.035618 0.035222       June      NaN       NaN      NaN      NaN 0.034826 0.035618      NaN      NaN        NaN      NaN       NaN       NaN
# ZL Oct25-Mar26 ZL Jul25-Aug25 0.047577 0.045327       June      NaN       NaN      NaN      NaN 0.043076 0.047577      NaN      NaN        NaN      NaN       NaN       NaN
# ZL Oct25-Mar26 ZL Sep25-Mar26 0.099672 0.064893    October      NaN       NaN      NaN      NaN 0.040790 0.036015      NaN      NaN   0.051972 0.099672  0.096017       NaN
# ZL May25-Oct25 ZL Mar25-Aug25 0.136125 0.080350     August      NaN       NaN 0.055897 0.070905 0.046279 0.076831 0.096065 0.136125        NaN      NaN       NaN       NaN
# ZL May25-Oct25 ZL Sep25-Oct25 0.068512 0.055991       June      NaN       NaN      NaN      NaN 0.041556 0.068512 0.050373 0.063523        NaN      NaN       NaN       NaN
# ZL May25-Oct25 ZL Mar25-Jul25 0.120217 0.096591       June      NaN       NaN 0.061907 0.081436 0.112160 0.120217 0.096345 0.107480        NaN      NaN       NaN       NaN
# ZL May25-Oct25 ZL Aug25-Oct25 0.061466 0.050868       June      NaN       NaN      NaN      NaN 0.034418 0.061466 0.048541 0.059046        NaN      NaN       NaN       NaN
# ZL May25-Oct25 ZL Aug25-Jan26 0.097956 0.067146  September      NaN       NaN      NaN 0.074109 0.034848 0.049191 0.059832 0.097392   0.097956 0.056693       NaN       NaN
# ZL May25-Oct25 ZL Mar25-Sep25 0.110066 0.074515     August      NaN       NaN 0.039924 0.070228 0.070023 0.087251 0.069598 0.110066        NaN      NaN       NaN       NaN
# ZL May25-Oct25 ZL Oct25-Jan26 0.128696 0.075813     August      NaN       NaN      NaN 0.039761 0.054734 0.073962 0.081915 0.128696        NaN      NaN       NaN       NaN
# ZL May25-Oct25 ZL Jul25-Sep25 0.089424 0.067289       July      NaN       NaN      NaN      NaN 0.044278 0.059551 0.089424 0.075901        NaN      NaN       NaN       NaN
# ZL May25-Oct25 ZL Oct25-Dec25 0.086537 0.060309     August      NaN       NaN      NaN 0.032728 0.051801 0.063087 0.067391 0.086537        NaN      NaN       NaN       NaN
# ZL May25-Oct25 ZL Oct25-May26 0.088618 0.071324     August      NaN       NaN      NaN 0.047901 0.060478 0.076063 0.083560 0.088618        NaN      NaN       NaN       NaN
# ZL May25-Oct25 ZL Jan26-Mar26 0.051569 0.051569     August      NaN       NaN      NaN      NaN      NaN      NaN      NaN 0.051569        NaN      NaN       NaN       NaN
# ZL May25-Oct25 ZL Aug25-Sep25 0.059245 0.059245       July      NaN       NaN      NaN      NaN      NaN      NaN 0.059245      NaN        NaN      NaN       NaN       NaN
# ZL May25-Oct25 ZL Dec25-May26 0.043334 0.041958     August      NaN       NaN      NaN      NaN 0.040583      NaN      NaN 0.043334        NaN      NaN       NaN       NaN
# ZL May25-Oct25 ZL Aug25-Dec25 0.085648 0.051529     August      NaN       NaN      NaN 0.038867 0.038714 0.048753 0.045663 0.085648        NaN      NaN       NaN       NaN
# ZL May25-Oct25 ZL Sep25-Jan26 0.098120 0.077166    October      NaN       NaN      NaN      NaN 0.060829 0.049890      NaN 0.081244   0.085470 0.098120  0.087444       NaN
# ZL May25-Oct25 ZL May25-Aug25 0.097395 0.077566     August      NaN       NaN      NaN      NaN 0.065904 0.080682 0.066285 0.097395        NaN      NaN       NaN       NaN
# ZL May25-Oct25 ZL May25-Sep25 0.097009 0.076929       June      NaN       NaN      NaN      NaN 0.044119 0.097009 0.082613 0.083973        NaN      NaN       NaN       NaN
# ZL May25-Oct25 ZL Dec25-Jan26 0.065994 0.065994     August      NaN       NaN      NaN      NaN      NaN      NaN      NaN 0.065994        NaN      NaN       NaN       NaN
# ZL May25-Oct25 ZL Jan26-Aug26 0.089222 0.069706     August      NaN       NaN      NaN      NaN 0.050191      NaN      NaN 0.089222        NaN      NaN       NaN       NaN
# ZL May25-Oct25 ZL Mar25-May25 0.126157 0.083109     August      NaN       NaN 0.078326 0.059464 0.093591 0.067030 0.074085 0.126157        NaN      NaN       NaN       NaN
# ZL May25-Oct25 ZL May25-Jul25 0.174608 0.116195       June      NaN       NaN      NaN      NaN 0.057876 0.174608 0.114902 0.117392        NaN      NaN       NaN       NaN
# ZL May25-Oct25 ZL Dec25-Mar26 0.077140 0.077140     August      NaN       NaN      NaN      NaN      NaN      NaN      NaN 0.077140        NaN      NaN       NaN       NaN
# ZL May25-Oct25 ZL Sep25-Dec25 0.080912 0.051807     August      NaN       NaN      NaN 0.035046 0.038243 0.048332 0.056504 0.080912        NaN      NaN       NaN       NaN
# ZL May25-Oct25 ZL Jul25-Aug25 0.096619 0.074742       July      NaN       NaN      NaN      NaN 0.051584 0.074556 0.096619 0.076208        NaN      NaN       NaN       NaN
# ZL May25-Oct25 ZL Sep25-Mar26 0.096000 0.060386     August      NaN       NaN      NaN      NaN 0.038265 0.051861 0.051262 0.096000   0.055954 0.068975       NaN       NaN
# ZL Mar25-Aug25 ZL Sep25-Oct25 0.063525 0.053418     August      NaN       NaN 0.045723 0.050108 0.047219 0.057192 0.056740 0.063525        NaN      NaN       NaN       NaN
# ZL Mar25-Aug25 ZL Mar25-Jul25 0.130494 0.098785     August      NaN       NaN 0.060539 0.068750 0.113682 0.120461      NaN 0.130494        NaN      NaN       NaN       NaN
# ZL Mar25-Aug25 ZL Aug25-Oct25 0.061845 0.055553     August      NaN       NaN 0.056270 0.049137 0.060078 0.057469 0.048522 0.061845        NaN      NaN       NaN       NaN
# ZL Mar25-Aug25 ZL Aug25-Jan26 0.131286 0.079296       June 0.037079  0.075151 0.121605 0.087896 0.049659 0.131286      NaN 0.097264   0.078625 0.072159       NaN  0.042239
# ZL Mar25-Aug25 ZL Mar25-Sep25 0.099442 0.075092      April      NaN       NaN 0.067329 0.099442 0.069773 0.081880 0.056487 0.075643        NaN      NaN       NaN       NaN
# ZL Mar25-Aug25 ZL Oct25-Jan26 0.088911 0.063900       July 0.043462  0.047935 0.050484 0.088783 0.067531 0.060358 0.088911 0.076422        NaN      NaN       NaN  0.051213
# ZL Mar25-Aug25 ZL Jul25-Sep25 0.115044 0.073501     August      NaN       NaN 0.043424 0.098634 0.050030 0.064146 0.069731 0.115044        NaN      NaN       NaN       NaN
# ZL Mar25-Aug25 ZL Oct25-Dec25 0.078214 0.064047     August      NaN       NaN 0.044275 0.073237 0.049618 0.074892      NaN 0.078214        NaN      NaN       NaN       NaN
# ZL Mar25-Aug25 ZL Oct25-May26 0.137762 0.073642       July 0.043100  0.048538 0.040475 0.086617 0.074260 0.079297 0.137762 0.115029        NaN      NaN       NaN  0.037698
# ZL Mar25-Aug25 ZL Jan26-Mar26 0.059071 0.057076       June      NaN       NaN 0.055081      NaN      NaN 0.059071      NaN      NaN        NaN      NaN       NaN       NaN
# ZL Mar25-Aug25 ZL Aug25-Sep25 0.059762 0.054469      April      NaN       NaN 0.057953 0.059762 0.056847 0.050624 0.049020 0.052611        NaN      NaN       NaN       NaN
# ZL Mar25-Aug25 ZL Dec25-May26 0.062229 0.055926      March      NaN       NaN 0.062229      NaN 0.051820 0.043835 0.061950 0.059794        NaN      NaN       NaN       NaN
# ZL Mar25-Aug25 ZL Aug25-Dec25 0.080263 0.051823      April      NaN       NaN 0.049713 0.080263 0.041044 0.040844 0.034390 0.064685        NaN      NaN       NaN       NaN
# ZL Mar25-Aug25 ZL Sep25-Jan26 0.105714 0.064079   November 0.036503  0.042585 0.045726 0.045231 0.053397 0.064647 0.059032 0.093449   0.064477 0.092425  0.105714  0.065765
# ZL Mar25-Aug25 ZL May25-Aug25 0.100841 0.074142     August      NaN       NaN 0.038766 0.082661 0.061839 0.086603      NaN 0.100841        NaN      NaN       NaN       NaN
# ZL Mar25-Aug25 ZL May25-Sep25 0.089075 0.074343      April      NaN       NaN 0.043287 0.089075 0.085482 0.068419 0.078410 0.081383        NaN      NaN       NaN       NaN
# ZL Mar25-Aug25 ZL Dec25-Jul26 0.048424 0.048064        May      NaN       NaN      NaN      NaN 0.048424      NaN      NaN 0.047705        NaN      NaN       NaN       NaN
# ZL Mar25-Aug25 ZL Dec25-Jan26 0.061785 0.054122       July      NaN       NaN 0.046498      NaN 0.057013 0.051194 0.061785      NaN        NaN      NaN       NaN       NaN
# ZL Mar25-Aug25 ZL Jan26-Aug26 0.097306 0.073838     August      NaN       NaN 0.042839      NaN 0.090489 0.051582 0.086974 0.097306        NaN      NaN       NaN       NaN
# ZL Mar25-Aug25 ZL Mar25-May25 0.097902 0.072453     August      NaN       NaN 0.048791 0.067294 0.067879 0.080396      NaN 0.097902        NaN      NaN       NaN       NaN
# ZL Mar25-Aug25 ZL May25-Jul25 0.140741 0.102077        May      NaN       NaN 0.073100      NaN 0.140741 0.073110      NaN 0.121357        NaN      NaN       NaN       NaN
# ZL Mar25-Aug25 ZL Dec25-Mar26 0.057193 0.050708      March      NaN       NaN 0.057193      NaN 0.051219 0.043712      NaN      NaN        NaN      NaN       NaN       NaN
# ZL Mar25-Aug25 ZL Sep25-Dec25 0.068080 0.048905     August      NaN       NaN 0.035659 0.045029 0.051987 0.037952 0.054721 0.068080        NaN      NaN       NaN       NaN
# ZL Mar25-Aug25 ZL Jul25-Aug25 0.129693 0.081500     August      NaN       NaN 0.060660 0.081696      NaN 0.053950      NaN 0.129693        NaN      NaN       NaN       NaN
# ZL Mar25-Aug25 ZL Sep25-Mar26 0.133977 0.065877    October 0.037007  0.045040 0.042231 0.051985 0.060121 0.049725 0.070842 0.090652   0.053108 0.133977  0.108504  0.047337
# ZL Sep25-Oct25 ZL Mar25-Jul25 0.093302 0.068488       June      NaN       NaN 0.073878      NaN      NaN 0.093302 0.062408 0.044362        NaN      NaN       NaN       NaN
# ZL Sep25-Oct25 ZL Aug25-Jan26 0.095637 0.060577     August      NaN       NaN      NaN 0.035305      NaN 0.036890      NaN 0.095637   0.074477      NaN       NaN       NaN
# ZL Sep25-Oct25 ZL Mar25-Sep25 0.081327 0.067884        May      NaN       NaN 0.075141 0.059997 0.081327 0.066177 0.047576 0.077087        NaN      NaN       NaN       NaN
# ZL Sep25-Oct25 ZL Oct25-Jan26 0.059355 0.050584     August      NaN       NaN      NaN 0.047146      NaN 0.045252      NaN 0.059355        NaN      NaN       NaN       NaN
# ZL Sep25-Oct25 ZL Oct25-May26 0.076345 0.062409       June      NaN       NaN      NaN 0.069733 0.031993 0.076345      NaN 0.071564        NaN      NaN       NaN       NaN
# ZL Sep25-Oct25 ZL Dec25-May26 0.041508 0.041508      April      NaN       NaN      NaN 0.041508      NaN      NaN      NaN      NaN        NaN      NaN       NaN       NaN
# ZL Sep25-Oct25 ZL Aug25-Dec25 0.029424 0.029424       June      NaN       NaN      NaN      NaN      NaN 0.029424      NaN      NaN        NaN      NaN       NaN       NaN
# ZL Sep25-Oct25 ZL Sep25-Jan26 0.080077 0.048987   November      NaN       NaN      NaN 0.042588      NaN 0.036721      NaN 0.040919   0.042303 0.051316  0.080077       NaN
# ZL Sep25-Oct25 ZL May25-Aug25 0.073311 0.065041     August      NaN       NaN      NaN      NaN 0.048842 0.071887 0.066125 0.073311        NaN      NaN       NaN       NaN
# ZL Sep25-Oct25 ZL May25-Sep25 0.064309 0.055304       June      NaN       NaN      NaN      NaN 0.048943 0.064309 0.058885 0.049079        NaN      NaN       NaN       NaN
# ZL Sep25-Oct25 ZL Jan26-Aug26 0.050441 0.050441      April      NaN       NaN      NaN 0.050441      NaN      NaN      NaN      NaN        NaN      NaN       NaN       NaN
# ZL Sep25-Oct25 ZL Mar25-May25 0.090970 0.067190     August      NaN       NaN      NaN      NaN      NaN 0.047584 0.063015 0.090970        NaN      NaN       NaN       NaN
# ZL Sep25-Oct25 ZL May25-Jul25 0.110410 0.087511       June      NaN       NaN      NaN      NaN      NaN 0.110410 0.065460 0.086663        NaN      NaN       NaN       NaN
# ZL Sep25-Oct25 ZL Sep25-Mar26 0.049791 0.037562      April      NaN       NaN      NaN 0.049791 0.036658 0.023819      NaN      NaN   0.030309 0.047235       NaN       NaN
# ZL Mar25-Jul25 ZL Aug25-Oct25 0.114470 0.071767     August      NaN       NaN 0.041936      NaN      NaN 0.069252 0.061410 0.114470        NaN      NaN       NaN       NaN
# ZL Mar25-Jul25 ZL Aug25-Jan26 0.086884 0.062643      April 0.049094  0.062601 0.083324 0.086884 0.049199 0.053889      NaN 0.083759   0.056517 0.034120       NaN  0.067044
# ZL Mar25-Jul25 ZL Mar25-Sep25 0.101976 0.079714     August      NaN       NaN 0.073449 0.077821 0.085054 0.073078 0.066904 0.101976        NaN      NaN       NaN       NaN
# ZL Mar25-Jul25 ZL Oct25-Jan26 0.106695 0.087093      March      NaN  0.046702 0.106695 0.101779 0.070307 0.093006 0.086790 0.104369        NaN      NaN       NaN       NaN
# ZL Mar25-Jul25 ZL Jul25-Sep25 0.112849 0.064636     August      NaN       NaN 0.046845 0.088242 0.036082 0.049147 0.054651 0.112849        NaN      NaN       NaN       NaN
# ZL Mar25-Jul25 ZL Oct25-Dec25 0.087131 0.071209      March      NaN       NaN 0.087131      NaN      NaN      NaN 0.064105 0.062391        NaN      NaN       NaN       NaN
# ZL Mar25-Jul25 ZL Oct25-May26 0.104120 0.077559     August      NaN  0.040442 0.042952 0.084297 0.082447 0.085028 0.103630 0.104120        NaN      NaN       NaN       NaN
# ZL Mar25-Jul25 ZL Aug25-Sep25 0.125433 0.076808       June      NaN       NaN 0.067683      NaN      NaN 0.125433 0.055272 0.058842        NaN      NaN       NaN       NaN
# ZL Mar25-Jul25 ZL Dec25-May26 0.064515 0.060153       July      NaN       NaN      NaN 0.061238      NaN 0.054707 0.064515      NaN        NaN      NaN       NaN       NaN
# ZL Mar25-Jul25 ZL Aug25-Dec25 0.060663 0.059261      March      NaN       NaN 0.060663      NaN      NaN 0.060149 0.056046 0.060185        NaN      NaN       NaN       NaN
# ZL Mar25-Jul25 ZL Sep25-Jan26 0.125243 0.069597      March      NaN  0.060852 0.125243 0.041348 0.065553 0.051197 0.070864 0.077880        NaN 0.074479  0.058955       NaN
# ZL Mar25-Jul25 ZL May25-Aug25 0.086569 0.066221        May      NaN       NaN 0.049934 0.050736 0.086569 0.077646      NaN      NaN        NaN      NaN       NaN       NaN
# ZL Mar25-Jul25 ZL May25-Sep25 0.088675 0.073859     August      NaN       NaN 0.040029 0.078976 0.086203 0.074025 0.075247 0.088675        NaN      NaN       NaN       NaN
# ZL Mar25-Jul25 ZL Dec25-Jul26 0.047630 0.047630       July      NaN       NaN      NaN      NaN      NaN      NaN 0.047630      NaN        NaN      NaN       NaN       NaN
# ZL Mar25-Jul25 ZL Dec25-Jan26 0.050547 0.050547      April      NaN       NaN      NaN 0.050547      NaN      NaN      NaN      NaN        NaN      NaN       NaN       NaN
# ZL Mar25-Jul25 ZL Jan26-Aug26 0.131428 0.104266       July      NaN       NaN      NaN 0.077104      NaN      NaN 0.131428      NaN        NaN      NaN       NaN       NaN
# ZL Mar25-Jul25 ZL Mar25-May25 0.088844 0.068934      April      NaN       NaN 0.052855 0.088844      NaN 0.071781      NaN 0.062257        NaN      NaN       NaN       NaN
# ZL Mar25-Jul25 ZL May25-Jul25 0.140226 0.089560      April      NaN       NaN 0.092894 0.140226      NaN 0.067051      NaN 0.058068        NaN      NaN       NaN       NaN
# ZL Mar25-Jul25 ZL Dec25-Mar26 0.059764 0.055379      April      NaN       NaN      NaN 0.059764      NaN      NaN 0.050994      NaN        NaN      NaN       NaN       NaN
# ZL Mar25-Jul25 ZL Sep25-Dec25 0.086667 0.064780      March      NaN       NaN 0.086667      NaN      NaN 0.040150 0.048618 0.083685        NaN      NaN       NaN       NaN
# ZL Mar25-Jul25 ZL Jul25-Aug25 0.129693 0.076906     August      NaN       NaN 0.063623 0.076607 0.060673 0.053933      NaN 0.129693        NaN      NaN       NaN       NaN
# ZL Mar25-Jul25 ZL Sep25-Mar26 0.125866 0.068352      March 0.035441  0.066423 0.125866 0.053701 0.054653 0.070267 0.063333 0.076219        NaN 0.078818  0.073378  0.053769
# ZL Aug25-Oct25 ZL Aug25-Jan26 0.093918 0.081006  September      NaN       NaN      NaN      NaN      NaN      NaN      NaN 0.087842   0.093918 0.061258       NaN       NaN
# ZL Aug25-Oct25 ZL Mar25-Sep25 0.072392 0.061785     August      NaN       NaN 0.068394 0.059243 0.059372 0.061854 0.049457 0.072392        NaN      NaN       NaN       NaN
# ZL Aug25-Oct25 ZL Oct25-Jan26 0.103924 0.103924     August      NaN       NaN      NaN      NaN      NaN      NaN      NaN 0.103924        NaN      NaN       NaN       NaN
# ZL Aug25-Oct25 ZL Oct25-May26 0.097698 0.079343     August      NaN       NaN      NaN 0.097244 0.043089      NaN      NaN 0.097698        NaN      NaN       NaN       NaN
# ZL Aug25-Oct25 ZL Dec25-May26 0.054966 0.054966     August      NaN       NaN      NaN      NaN      NaN      NaN      NaN 0.054966        NaN      NaN       NaN       NaN
# ZL Aug25-Oct25 ZL Sep25-Jan26 0.084044 0.058730   November      NaN       NaN      NaN      NaN      NaN 0.027452      NaN 0.051963   0.069368 0.060825  0.084044       NaN
# ZL Aug25-Oct25 ZL May25-Aug25 0.083890 0.068685     August      NaN       NaN      NaN      NaN 0.056362 0.066111 0.068377 0.083890        NaN      NaN       NaN       NaN
# ZL Aug25-Oct25 ZL May25-Sep25 0.066966 0.062598       June      NaN       NaN      NaN      NaN 0.059035 0.066966 0.063675 0.060715        NaN      NaN       NaN       NaN
# ZL Aug25-Oct25 ZL Dec25-Jan26 0.053711 0.053711     August      NaN       NaN      NaN      NaN      NaN      NaN      NaN 0.053711        NaN      NaN       NaN       NaN
# ZL Aug25-Oct25 ZL Jan26-Aug26 0.037045 0.037045     August      NaN       NaN      NaN      NaN      NaN      NaN      NaN 0.037045        NaN      NaN       NaN       NaN
# ZL Aug25-Oct25 ZL Mar25-May25 0.076826 0.060706     August      NaN       NaN      NaN      NaN      NaN 0.054906 0.050387 0.076826        NaN      NaN       NaN       NaN
# ZL Aug25-Oct25 ZL May25-Jul25 0.102355 0.068649       June      NaN       NaN      NaN      NaN      NaN 0.102355 0.055287 0.048306        NaN      NaN       NaN       NaN
# ZL Aug25-Oct25 ZL Dec25-Mar26 0.024997 0.024997     August      NaN       NaN      NaN      NaN      NaN      NaN      NaN 0.024997        NaN      NaN       NaN       NaN
# ZL Aug25-Oct25 ZL Sep25-Mar26 0.063219 0.047144    October      NaN       NaN      NaN      NaN      NaN 0.022466      NaN 0.045971   0.056920 0.063219       NaN       NaN
# ZL Aug25-Jan26 ZL Mar25-Sep25 0.112485 0.068833  September 0.064168  0.038306 0.042467 0.071527 0.083216 0.052154 0.054032 0.101512   0.112485 0.063852       NaN  0.073441
# ZL Aug25-Jan26 ZL Oct25-Jan26 0.170896 0.119141  September      NaN       NaN      NaN      NaN      NaN      NaN      NaN 0.085266   0.170896 0.071523  0.148880       NaN
# ZL Aug25-Jan26 ZL Jul25-Sep25 0.083060 0.062095     August      NaN       NaN      NaN      NaN      NaN 0.035931      NaN 0.083060   0.071868 0.057522       NaN       NaN
# ZL Aug25-Jan26 ZL Oct25-Dec25 0.061841 0.060677  September      NaN       NaN      NaN      NaN      NaN      NaN      NaN 0.059513   0.061841      NaN       NaN       NaN
# ZL Aug25-Jan26 ZL Oct25-May26 0.139540 0.099873    October      NaN       NaN      NaN 0.061970 0.057532      NaN      NaN 0.105544   0.127464 0.139540  0.107189       NaN
# ZL Aug25-Jan26 ZL Jan26-Mar26 0.062127 0.049442  September      NaN       NaN      NaN      NaN 0.036757      NaN      NaN      NaN   0.062127      NaN       NaN       NaN
# ZL Aug25-Jan26 ZL Aug25-Sep25 0.059706 0.051633  September      NaN       NaN      NaN 0.043693      NaN      NaN      NaN      NaN   0.059706 0.051500       NaN       NaN
# ZL Aug25-Jan26 ZL Dec25-May26 0.063300 0.054163  September      NaN       NaN      NaN 0.048601 0.046342      NaN      NaN      NaN   0.063300 0.058410       NaN       NaN
# ZL Aug25-Jan26 ZL Aug25-Dec25 0.133004 0.133004  September      NaN       NaN      NaN      NaN      NaN      NaN      NaN      NaN   0.133004      NaN       NaN       NaN
# ZL Aug25-Jan26 ZL Sep25-Jan26 0.079978 0.062360  September      NaN       NaN      NaN 0.030559      NaN      NaN      NaN      NaN   0.079978 0.076543       NaN       NaN
# ZL Aug25-Jan26 ZL May25-Aug25 0.105397 0.080386     August      NaN       NaN      NaN 0.068586 0.045654      NaN      NaN 0.105397   0.093949 0.088345       NaN       NaN
# ZL Aug25-Jan26 ZL May25-Sep25 0.113195 0.070738     August      NaN       NaN      NaN 0.051241 0.046377 0.059468 0.076697 0.113195   0.073408 0.074777       NaN       NaN
# ZL Aug25-Jan26 ZL Dec25-Jul26 0.040495 0.040495  September      NaN       NaN      NaN      NaN      NaN      NaN      NaN      NaN   0.040495      NaN       NaN       NaN
# ZL Aug25-Jan26 ZL Dec25-Jan26 0.062555 0.062555  September      NaN       NaN      NaN      NaN      NaN      NaN      NaN      NaN   0.062555      NaN       NaN       NaN
# ZL Aug25-Jan26 ZL Jan26-Aug26 0.089819 0.070131  September      NaN       NaN      NaN      NaN 0.037320      NaN      NaN      NaN   0.089819 0.083254       NaN       NaN
# ZL Aug25-Jan26 ZL Mar25-May25 0.081650 0.060369     August 0.056097  0.042442 0.076445 0.051640 0.064684 0.050723      NaN 0.081650   0.052180 0.057626       NaN  0.070198
# ZL Aug25-Jan26 ZL May25-Jul25 0.133476 0.071690     August      NaN  0.049599 0.096591 0.050248 0.058822 0.061671      NaN 0.133476   0.063640 0.059472       NaN       NaN
# ZL Aug25-Jan26 ZL Dec25-Mar26 0.058383 0.047489  September      NaN       NaN      NaN      NaN 0.036594      NaN      NaN      NaN   0.058383      NaN       NaN       NaN
# ZL Aug25-Jan26 ZL Sep25-Dec25 0.082497 0.063532    October      NaN       NaN      NaN 0.036324      NaN      NaN      NaN      NaN   0.071775 0.082497       NaN       NaN
# ZL Aug25-Jan26 ZL Jul25-Aug25 0.107342 0.075533     August      NaN       NaN      NaN 0.054535      NaN 0.043589      NaN 0.107342   0.096665      NaN       NaN       NaN
# ZL Aug25-Jan26 ZL Sep25-Mar26 0.103735 0.064939   November      NaN       NaN      NaN 0.035769 0.043659      NaN      NaN      NaN   0.075270 0.066260  0.103735       NaN
# ZL Mar25-Sep25 ZL Oct25-Jan26 0.102960 0.062885     August 0.041323  0.052411 0.029921 0.091042 0.061838 0.052172 0.082424 0.102960        NaN      NaN       NaN  0.051870
# ZL Mar25-Sep25 ZL Jul25-Sep25 0.112849 0.067139     August      NaN       NaN 0.049307 0.085911 0.048507 0.051329 0.054933 0.112849        NaN      NaN       NaN       NaN
# ZL Mar25-Sep25 ZL Oct25-Dec25 0.084835 0.058281     August      NaN       NaN 0.043712 0.058942 0.052899 0.049147 0.060151 0.084835        NaN      NaN       NaN       NaN
# ZL Mar25-Sep25 ZL Oct25-May26 0.139753 0.066940       July 0.042070  0.038307 0.035030 0.090210 0.077580 0.050936 0.139753 0.094372        NaN      NaN       NaN  0.034200
# ZL Mar25-Sep25 ZL Jan26-Mar26 0.074549 0.065278        May      NaN       NaN      NaN      NaN 0.074549      NaN      NaN 0.056008        NaN      NaN       NaN       NaN
# ZL Mar25-Sep25 ZL Aug25-Sep25 0.083454 0.059737     August      NaN       NaN 0.051769 0.058849 0.056754 0.055328 0.052266 0.083454        NaN      NaN       NaN       NaN
# ZL Mar25-Sep25 ZL Dec25-May26 0.066699 0.054534      April      NaN       NaN 0.052364 0.066699 0.050483      NaN 0.053314 0.049808        NaN      NaN       NaN       NaN
# ZL Mar25-Sep25 ZL Aug25-Dec25 0.082465 0.061010     August      NaN       NaN 0.060872 0.079508 0.052547 0.046058 0.044608 0.082465        NaN      NaN       NaN       NaN
# ZL Mar25-Sep25 ZL Sep25-Jan26 0.107848 0.066242    October 0.046231  0.044199 0.048146 0.056414 0.067572 0.058365 0.067457 0.087854   0.065418 0.107848  0.103758  0.041643
# ZL Mar25-Sep25 ZL May25-Aug25 0.176105 0.091516        May      NaN       NaN 0.048025 0.093985 0.176105 0.103820 0.066018 0.061142        NaN      NaN       NaN       NaN
# ZL Mar25-Sep25 ZL May25-Sep25 0.093556 0.072960      April      NaN       NaN 0.038424 0.093556 0.071720 0.086308 0.089103 0.058651        NaN      NaN       NaN       NaN
# ZL Mar25-Sep25 ZL Dec25-Jul26 0.067103 0.046004     August      NaN       NaN 0.034730 0.049273 0.048443 0.039937 0.036536 0.067103        NaN      NaN       NaN       NaN
# ZL Mar25-Sep25 ZL Dec25-Jan26 0.063107 0.055182      April      NaN       NaN 0.051154 0.063107 0.053658 0.062662 0.050572 0.049937        NaN      NaN       NaN       NaN
# ZL Mar25-Sep25 ZL Jan26-Aug26 0.074578 0.060181     August      NaN       NaN      NaN      NaN 0.051524 0.045951 0.068670 0.074578        NaN      NaN       NaN       NaN
# ZL Mar25-Sep25 ZL Mar25-May25 0.109184 0.088255       July      NaN       NaN      NaN 0.082501 0.086123 0.072596 0.109184 0.090874        NaN      NaN       NaN       NaN
# ZL Mar25-Sep25 ZL May25-Jul25 0.190859 0.126222      April      NaN       NaN 0.071999 0.190859 0.146059 0.136879 0.115503 0.096036        NaN      NaN       NaN       NaN
# ZL Mar25-Sep25 ZL Dec25-Mar26 0.063819 0.048529        May      NaN       NaN 0.043558 0.046650 0.063819 0.037113 0.054069 0.045965        NaN      NaN       NaN       NaN
# ZL Mar25-Sep25 ZL Sep25-Dec25 0.061033 0.049735       June      NaN       NaN 0.044674 0.043737 0.047416 0.061033 0.053467 0.048084        NaN      NaN       NaN       NaN
# ZL Mar25-Sep25 ZL Jul25-Aug25 0.116975 0.069014     August      NaN       NaN 0.040207 0.058635 0.064283 0.050218 0.083763 0.116975        NaN      NaN       NaN       NaN
# ZL Mar25-Sep25 ZL Sep25-Mar26 0.151554 0.069511    October 0.038618  0.027768 0.046910 0.047091 0.082248 0.083524 0.050539 0.084623   0.065712 0.151554  0.113134  0.042417
# ZL Oct25-Jan26 ZL Jul25-Sep25 0.092321 0.066482     August      NaN       NaN      NaN      NaN      NaN 0.047885 0.059240 0.092321        NaN      NaN       NaN       NaN
# ZL Oct25-Jan26 ZL Aug25-Sep25 0.081634 0.081634     August      NaN       NaN      NaN      NaN      NaN      NaN      NaN 0.081634        NaN      NaN       NaN       NaN
# ZL Oct25-Jan26 ZL Aug25-Dec25 0.058617 0.058617     August      NaN       NaN      NaN      NaN      NaN      NaN      NaN 0.058617        NaN      NaN       NaN       NaN
# ZL Oct25-Jan26 ZL Sep25-Jan26 0.087469 0.064410    October      NaN       NaN      NaN      NaN      NaN 0.070157      NaN 0.043788   0.042711 0.087469  0.077925       NaN
# ZL Oct25-Jan26 ZL May25-Aug25 0.101899 0.069275     August      NaN       NaN      NaN      NaN 0.059994 0.048914 0.066292 0.101899        NaN      NaN       NaN       NaN
# ZL Oct25-Jan26 ZL May25-Sep25 0.079901 0.060951     August      NaN       NaN      NaN      NaN 0.044174 0.050576 0.069151 0.079901        NaN      NaN       NaN       NaN
# ZL Oct25-Jan26 ZL Mar25-May25 0.096376 0.061831     August      NaN  0.051659 0.042119 0.056103 0.061547 0.063520 0.061494 0.096376        NaN      NaN       NaN       NaN
# ZL Oct25-Jan26 ZL May25-Jul25 0.124370 0.082444     August      NaN  0.059408 0.071967 0.055512 0.075673 0.116170 0.074006 0.124370        NaN      NaN       NaN       NaN
# ZL Oct25-Jan26 ZL Sep25-Dec25 0.043163 0.038281     August      NaN       NaN      NaN      NaN      NaN 0.033399      NaN 0.043163        NaN      NaN       NaN       NaN
# ZL Oct25-Jan26 ZL Jul25-Aug25 0.098875 0.068847       July      NaN       NaN      NaN      NaN      NaN 0.038818 0.098875      NaN        NaN      NaN       NaN       NaN
# ZL Oct25-Jan26 ZL Sep25-Mar26 0.075946 0.052591   November      NaN       NaN      NaN      NaN 0.029979      NaN      NaN 0.045362   0.038436 0.073231  0.075946       NaN
# ZL Jul25-Sep25 ZL Oct25-Dec25 0.072166 0.060437       July      NaN       NaN      NaN      NaN      NaN 0.048709 0.072166      NaN        NaN      NaN       NaN       NaN
# ZL Jul25-Sep25 ZL Oct25-May26 0.128057 0.085289       July      NaN       NaN      NaN      NaN 0.044952 0.058917 0.128057 0.109230        NaN      NaN       NaN       NaN
# ZL Jul25-Sep25 ZL Dec25-May26 0.047551 0.039420        May      NaN       NaN      NaN      NaN 0.047551 0.034525      NaN 0.036185        NaN      NaN       NaN       NaN
# ZL Jul25-Sep25 ZL Aug25-Dec25 0.040688 0.040688       June      NaN       NaN      NaN      NaN      NaN 0.040688      NaN      NaN        NaN      NaN       NaN       NaN
# ZL Jul25-Sep25 ZL Sep25-Jan26 0.100376 0.053286  September      NaN       NaN      NaN 0.029669      NaN 0.027430      NaN 0.055671   0.100376      NaN       NaN       NaN
# ZL Jul25-Sep25 ZL May25-Aug25 0.097430 0.080364     August      NaN       NaN      NaN      NaN 0.088022 0.071534 0.064471 0.097430        NaN      NaN       NaN       NaN
# ZL Jul25-Sep25 ZL May25-Sep25 0.080232 0.066347     August      NaN       NaN      NaN      NaN 0.060945 0.066469 0.057742 0.080232        NaN      NaN       NaN       NaN
# ZL Jul25-Sep25 ZL Dec25-Jan26 0.059866 0.059866     August      NaN       NaN      NaN      NaN      NaN      NaN      NaN 0.059866        NaN      NaN       NaN       NaN
# ZL Jul25-Sep25 ZL Jan26-Aug26 0.067761 0.064729       June      NaN       NaN      NaN      NaN      NaN 0.067761      NaN 0.061696        NaN      NaN       NaN       NaN
# ZL Jul25-Sep25 ZL Mar25-May25 0.119896 0.070167     August      NaN       NaN      NaN 0.049208 0.054493      NaN 0.057073 0.119896        NaN      NaN       NaN       NaN
# ZL Jul25-Sep25 ZL May25-Jul25 0.072870 0.061082     August      NaN       NaN      NaN      NaN 0.059533 0.054815 0.057112 0.072870        NaN      NaN       NaN       NaN
# ZL Jul25-Sep25 ZL Dec25-Mar26 0.051469 0.045080        May      NaN       NaN      NaN      NaN 0.051469 0.036380      NaN 0.047392        NaN      NaN       NaN       NaN
# ZL Jul25-Sep25 ZL Sep25-Dec25 0.032188 0.032188       June      NaN       NaN      NaN      NaN      NaN 0.032188      NaN      NaN        NaN      NaN       NaN       NaN
# ZL Jul25-Sep25 ZL Sep25-Mar26 0.083304 0.055128    October      NaN       NaN      NaN 0.039238 0.054561 0.035331      NaN      NaN   0.063204 0.083304       NaN       NaN
# ZL Oct25-Dec25 ZL Sep25-Jan26 0.102593 0.054393   November      NaN       NaN      NaN      NaN      NaN 0.031017      NaN 0.029569        NaN      NaN  0.102593       NaN
# ZL Oct25-Dec25 ZL May25-Aug25 0.056123 0.051251     August      NaN       NaN      NaN      NaN 0.046555 0.051074      NaN 0.056123        NaN      NaN       NaN       NaN
# ZL Oct25-Dec25 ZL May25-Sep25 0.074051 0.055587       July      NaN       NaN      NaN      NaN 0.047033 0.043181 0.074051 0.058081        NaN      NaN       NaN       NaN
# ZL Oct25-Dec25 ZL Mar25-May25 0.082137 0.062636     August      NaN       NaN 0.059913      NaN      NaN 0.048910 0.059584 0.082137        NaN      NaN       NaN       NaN
# ZL Oct25-Dec25 ZL Sep25-Mar26 0.057643 0.039673        May      NaN       NaN      NaN      NaN 0.057643 0.021703      NaN      NaN        NaN      NaN       NaN       NaN
# ZL Oct25-May26 ZL Aug25-Sep25 0.081147 0.073098     August      NaN       NaN      NaN      NaN 0.065049      NaN      NaN 0.081147        NaN      NaN       NaN       NaN
# ZL Oct25-May26 ZL Aug25-Dec25 0.069174 0.043547     August      NaN       NaN      NaN 0.030900 0.030566      NaN      NaN 0.069174        NaN      NaN       NaN       NaN
# ZL Oct25-May26 ZL Sep25-Jan26 0.192535 0.076971    October      NaN       NaN      NaN      NaN 0.033267 0.045327      NaN 0.041122   0.052796 0.192535  0.096777       NaN
# ZL Oct25-May26 ZL May25-Aug25 0.127365 0.082112       July      NaN       NaN      NaN      NaN 0.061990 0.051515 0.127365 0.087576        NaN      NaN       NaN       NaN
# ZL Oct25-May26 ZL May25-Sep25 0.111182 0.076247     August      NaN       NaN      NaN      NaN 0.054491 0.059549 0.079768 0.111182        NaN      NaN       NaN       NaN
# ZL Oct25-May26 ZL Mar25-May25 0.092871 0.073175        May      NaN  0.049151 0.058350 0.067960 0.092871 0.070328 0.091625 0.081941        NaN      NaN       NaN       NaN
# ZL Oct25-May26 ZL May25-Jul25 0.106719 0.067984       July      NaN  0.060011 0.051865 0.039906 0.057836 0.068908 0.106719 0.090645        NaN      NaN       NaN       NaN
# ZL Oct25-May26 ZL Sep25-Dec25 0.061796 0.039499       June      NaN       NaN      NaN      NaN 0.030811 0.061796      NaN 0.025891        NaN      NaN       NaN       NaN
# ZL Oct25-May26 ZL Jul25-Aug25 0.077637 0.053337       July      NaN       NaN      NaN      NaN 0.042930 0.039445 0.077637      NaN        NaN      NaN       NaN       NaN
# ZL Oct25-May26 ZL Sep25-Mar26 0.128361 0.067285    October      NaN       NaN      NaN      NaN 0.040065 0.039418      NaN 0.040870   0.053451 0.128361  0.101547       NaN
# ZL Jan26-Mar26 ZL Aug25-Dec25 0.031508 0.031508        May      NaN       NaN      NaN      NaN 0.031508      NaN      NaN      NaN        NaN      NaN       NaN       NaN
# ZL Jan26-Mar26 ZL Sep25-Jan26 0.087727 0.087727   November      NaN       NaN      NaN      NaN      NaN      NaN      NaN      NaN        NaN      NaN  0.087727       NaN
# ZL Jan26-Mar26 ZL May25-Sep25 0.055196 0.053067     August      NaN       NaN      NaN      NaN 0.050938      NaN      NaN 0.055196        NaN      NaN       NaN       NaN
# ZL Jan26-Mar26 ZL Mar25-May25 0.112298 0.112298     August      NaN       NaN      NaN      NaN      NaN      NaN      NaN 0.112298        NaN      NaN       NaN       NaN
# ZL Jan26-Mar26 ZL May25-Jul25 0.104679 0.095831     August      NaN       NaN      NaN      NaN      NaN 0.086983      NaN 0.104679        NaN      NaN       NaN       NaN
# ZL Jan26-Mar26 ZL Sep25-Mar26 0.071186 0.071186   November      NaN       NaN      NaN      NaN      NaN      NaN      NaN      NaN        NaN      NaN  0.071186       NaN
# ZL Aug25-Sep25 ZL Dec25-May26 0.038714 0.038714        May      NaN       NaN      NaN      NaN 0.038714      NaN      NaN      NaN        NaN      NaN       NaN       NaN
# ZL Aug25-Sep25 ZL Sep25-Jan26 0.053647 0.044453  September      NaN       NaN      NaN 0.036293      NaN      NaN      NaN      NaN   0.053647 0.043420       NaN       NaN
# ZL Aug25-Sep25 ZL May25-Aug25 0.081761 0.063642     August      NaN       NaN      NaN      NaN 0.065798 0.057485 0.049522 0.081761        NaN      NaN       NaN       NaN
# ZL Aug25-Sep25 ZL May25-Sep25 0.076360 0.069108        May      NaN       NaN      NaN      NaN 0.076360 0.056474 0.068408 0.075188        NaN      NaN       NaN       NaN
# ZL Aug25-Sep25 ZL Jan26-Aug26 0.039730 0.039730        May      NaN       NaN      NaN      NaN 0.039730      NaN      NaN      NaN        NaN      NaN       NaN       NaN
# ZL Aug25-Sep25 ZL Mar25-May25 0.097589 0.067291     August      NaN       NaN      NaN      NaN      NaN 0.049472 0.054811 0.097589        NaN      NaN       NaN       NaN
# ZL Aug25-Sep25 ZL May25-Jul25 0.072539 0.063036     August      NaN       NaN      NaN      NaN      NaN      NaN 0.053533 0.072539        NaN      NaN       NaN       NaN
# ZL Aug25-Sep25 ZL Sep25-Mar26 0.048373 0.041600  September      NaN       NaN      NaN 0.036915 0.040178      NaN      NaN      NaN   0.048373 0.040935       NaN       NaN
# ZL Dec25-May26 ZL Aug25-Dec25 0.037073 0.034888      April      NaN       NaN      NaN 0.037073 0.032703      NaN      NaN      NaN        NaN      NaN       NaN       NaN
# ZL Dec25-May26 ZL Sep25-Jan26 0.110434 0.099612    October      NaN       NaN      NaN      NaN      NaN      NaN      NaN      NaN        NaN 0.110434  0.088790       NaN
# ZL Dec25-May26 ZL May25-Aug25 0.096394 0.080183       July      NaN       NaN      NaN      NaN      NaN 0.063971 0.096394      NaN        NaN      NaN       NaN       NaN
# ZL Dec25-May26 ZL May25-Sep25 0.101817 0.065762     August      NaN       NaN      NaN      NaN 0.040382 0.036786 0.084062 0.101817        NaN      NaN       NaN       NaN
# ZL Dec25-May26 ZL Mar25-May25 0.151331 0.096904     August      NaN       NaN      NaN 0.068709      NaN 0.077359 0.090217 0.151331        NaN      NaN       NaN       NaN
# ZL Dec25-May26 ZL May25-Jul25 0.131880 0.102450     August      NaN       NaN      NaN      NaN      NaN 0.088968 0.086500 0.131880        NaN      NaN       NaN       NaN
# ZL Dec25-May26 ZL Jul25-Aug25 0.044117 0.044117        May      NaN       NaN      NaN      NaN 0.044117      NaN      NaN      NaN        NaN      NaN       NaN       NaN
# ZL Dec25-May26 ZL Sep25-Mar26 0.104608 0.079116    October      NaN       NaN      NaN      NaN      NaN      NaN      NaN      NaN        NaN 0.104608  0.053624       NaN
# ZL Aug25-Dec25 ZL Sep25-Jan26 0.117468 0.072221   November      NaN       NaN      NaN 0.030571      NaN      NaN      NaN      NaN   0.052094 0.088753  0.117468       NaN
# ZL Aug25-Dec25 ZL May25-Aug25 0.067086 0.052897        May      NaN       NaN      NaN 0.041244 0.067086 0.064604 0.038791 0.052758        NaN      NaN       NaN       NaN
# ZL Aug25-Dec25 ZL May25-Sep25 0.076146 0.060228     August      NaN       NaN      NaN 0.042569 0.044982 0.067021 0.070423 0.076146        NaN      NaN       NaN       NaN
# ZL Aug25-Dec25 ZL Jan26-Aug26 0.061084 0.042125      April      NaN       NaN      NaN 0.061084 0.023165      NaN      NaN      NaN        NaN      NaN       NaN       NaN
# ZL Aug25-Dec25 ZL Mar25-May25 0.066410 0.061763       June      NaN       NaN 0.061978      NaN      NaN 0.066410 0.057220 0.061441        NaN      NaN       NaN       NaN
# ZL Aug25-Dec25 ZL May25-Jul25 0.068496 0.064488       June      NaN       NaN      NaN      NaN      NaN 0.068496 0.057631 0.067338        NaN      NaN       NaN       NaN
# ZL Aug25-Dec25 ZL Dec25-Mar26 0.037181 0.037181        May      NaN       NaN      NaN      NaN 0.037181      NaN      NaN      NaN        NaN      NaN       NaN       NaN
# ZL Aug25-Dec25 ZL Jul25-Aug25 0.033858 0.033858       June      NaN       NaN      NaN      NaN      NaN 0.033858      NaN      NaN        NaN      NaN       NaN       NaN
# ZL Aug25-Dec25 ZL Sep25-Mar26 0.095896 0.051381    October      NaN       NaN      NaN 0.030860 0.040692      NaN      NaN      NaN   0.038078 0.095896       NaN       NaN
# ZL Sep25-Jan26 ZL May25-Aug25 0.107757 0.065488    October      NaN       NaN      NaN 0.036808 0.054241 0.068225 0.050223 0.078909   0.057108 0.107757  0.070635       NaN
# ZL Sep25-Jan26 ZL May25-Sep25 0.096223 0.067952   November      NaN       NaN      NaN 0.062489 0.038076 0.064268 0.062505 0.072646   0.079459      NaN  0.096223       NaN
# ZL Sep25-Jan26 ZL Dec25-Jan26 0.099615 0.099615   November      NaN       NaN      NaN      NaN      NaN      NaN      NaN      NaN        NaN      NaN  0.099615       NaN
# ZL Sep25-Jan26 ZL Jan26-Aug26 0.238026 0.130565    October      NaN       NaN      NaN      NaN      NaN      NaN      NaN      NaN   0.063694 0.238026  0.089974       NaN
# ZL Sep25-Jan26 ZL Mar25-May25 0.106431 0.068190    October      NaN  0.052726 0.042287 0.062729 0.077178 0.071083 0.063504 0.069676        NaN 0.106431  0.068095       NaN
# ZL Sep25-Jan26 ZL May25-Jul25 0.089932 0.066973      March      NaN  0.048065 0.089932 0.050585 0.068780 0.066564 0.061924 0.081238        NaN 0.081296  0.054371       NaN
# ZL Sep25-Jan26 ZL Dec25-Mar26 0.060126 0.060126   November      NaN       NaN      NaN      NaN      NaN      NaN      NaN      NaN        NaN      NaN  0.060126       NaN
# ZL Sep25-Jan26 ZL Sep25-Dec25 0.086099 0.086099   November      NaN       NaN      NaN      NaN      NaN      NaN      NaN      NaN        NaN      NaN  0.086099       NaN
# ZL Sep25-Jan26 ZL Jul25-Aug25 0.091395 0.065746    October      NaN       NaN      NaN      NaN      NaN 0.036177      NaN 0.063695   0.071718 0.091395       NaN       NaN
# ZL Sep25-Jan26 ZL Sep25-Mar26 0.140674 0.140674   November      NaN       NaN      NaN      NaN      NaN      NaN      NaN      NaN        NaN      NaN  0.140674       NaN
# ZL May25-Aug25 ZL May25-Sep25 0.099020 0.081633       June      NaN       NaN      NaN      NaN 0.057670 0.099020 0.090630 0.079213        NaN      NaN       NaN       NaN
# ZL May25-Aug25 ZL Dec25-Jan26 0.067482 0.062304       July      NaN       NaN      NaN      NaN      NaN 0.057126 0.067482      NaN        NaN      NaN       NaN       NaN
# ZL May25-Aug25 ZL Jan26-Aug26 0.105844 0.105844       July      NaN       NaN      NaN      NaN      NaN      NaN 0.105844      NaN        NaN      NaN       NaN       NaN
# ZL May25-Aug25 ZL Mar25-May25 0.097902 0.070100     August      NaN       NaN      NaN 0.051670 0.062329 0.068500      NaN 0.097902        NaN      NaN       NaN       NaN
# ZL May25-Aug25 ZL May25-Jul25 0.146023 0.124984       June      NaN       NaN      NaN      NaN      NaN 0.146023      NaN 0.103944        NaN      NaN       NaN       NaN
# ZL May25-Aug25 ZL Sep25-Dec25 0.061993 0.047195     August      NaN       NaN      NaN 0.036146 0.039823 0.048818 0.049196 0.061993        NaN      NaN       NaN       NaN
# ZL May25-Aug25 ZL Jul25-Aug25 0.109462 0.084407     August      NaN       NaN      NaN      NaN      NaN 0.059352      NaN 0.109462        NaN      NaN       NaN       NaN
# ZL May25-Aug25 ZL Sep25-Mar26 0.091187 0.057994     August      NaN       NaN      NaN 0.040472 0.048265 0.052259 0.056235 0.091187   0.064084 0.053455       NaN       NaN
# ZL May25-Sep25 ZL Dec25-Jul26 0.095263 0.059421       July      NaN       NaN      NaN      NaN      NaN 0.040236 0.095263 0.042764        NaN      NaN       NaN       NaN
# ZL May25-Sep25 ZL Dec25-Jan26 0.071547 0.058468       July      NaN       NaN      NaN      NaN 0.042957 0.058633 0.071547 0.060735        NaN      NaN       NaN       NaN
# ZL May25-Sep25 ZL Jan26-Aug26 0.100497 0.066478     August      NaN       NaN      NaN      NaN 0.036266 0.051649 0.077499 0.100497        NaN      NaN       NaN       NaN
# ZL May25-Sep25 ZL Mar25-May25 0.109184 0.074946       July      NaN       NaN 0.051293 0.049326 0.062693 0.086308 0.109184 0.090874        NaN      NaN       NaN       NaN
# ZL May25-Sep25 ZL May25-Jul25 0.144240 0.097088       June      NaN       NaN      NaN      NaN 0.056115 0.144240 0.115126 0.072870        NaN      NaN       NaN       NaN
# ZL May25-Sep25 ZL Dec25-Mar26 0.059682 0.051970     August      NaN       NaN      NaN      NaN 0.058307 0.044445 0.045448 0.059682        NaN      NaN       NaN       NaN
# ZL May25-Sep25 ZL Sep25-Dec25 0.055228 0.045298       July      NaN       NaN      NaN 0.036975 0.037477 0.049033 0.055228 0.047776        NaN      NaN       NaN       NaN
# ZL May25-Sep25 ZL Jul25-Aug25 0.079122 0.062789     August      NaN       NaN      NaN      NaN 0.040389      NaN 0.068857 0.079122        NaN      NaN       NaN       NaN
# ZL May25-Sep25 ZL Sep25-Mar26 0.098807 0.068069    October      NaN       NaN      NaN 0.041571 0.075249 0.056904 0.057191 0.081490   0.065270 0.098807       NaN       NaN
# ZL Dec25-Jul26 ZL Mar25-May25 0.109727 0.109727     August      NaN       NaN      NaN      NaN      NaN      NaN      NaN 0.109727        NaN      NaN       NaN       NaN
# ZL Dec25-Jul26 ZL Sep25-Mar26 0.054280 0.054280    October      NaN       NaN      NaN      NaN      NaN      NaN      NaN      NaN        NaN 0.054280       NaN       NaN
# ZL Dec25-Jan26 ZL Mar25-May25 0.092666 0.071676     August      NaN       NaN      NaN 0.068299      NaN 0.060176 0.065564 0.092666        NaN      NaN       NaN       NaN
# ZL Dec25-Jan26 ZL May25-Jul25 0.098421 0.085208       June      NaN       NaN      NaN      NaN      NaN 0.098421 0.088695 0.068509        NaN      NaN       NaN       NaN
# ZL Dec25-Jan26 ZL Sep25-Mar26 0.058143 0.058143   November      NaN       NaN      NaN      NaN      NaN      NaN      NaN      NaN        NaN      NaN  0.058143       NaN
# ZL Jan26-Aug26 ZL Mar25-May25 0.118422 0.096201     August      NaN       NaN      NaN 0.084333      NaN      NaN 0.085848 0.118422        NaN      NaN       NaN       NaN
# ZL Jan26-Aug26 ZL May25-Jul25 0.117452 0.100197     August      NaN       NaN      NaN      NaN      NaN 0.105695 0.077443 0.117452        NaN      NaN       NaN       NaN
# ZL Jan26-Aug26 ZL Sep25-Mar26 0.173798 0.098603    October      NaN       NaN      NaN      NaN      NaN      NaN      NaN      NaN   0.053014 0.173798  0.068998       NaN
# ZL Mar25-May25 ZL May25-Jul25 0.138086 0.090890      April      NaN       NaN 0.099578 0.138086      NaN 0.066165      NaN 0.059731        NaN      NaN       NaN       NaN
# ZL Mar25-May25 ZL Dec25-Mar26 0.059396 0.052628     August      NaN       NaN      NaN 0.045860      NaN      NaN      NaN 0.059396        NaN      NaN       NaN       NaN
# ZL Mar25-May25 ZL Sep25-Dec25 0.089449 0.068624      March      NaN       NaN 0.089449      NaN      NaN 0.049145 0.055825 0.080078        NaN      NaN       NaN       NaN
# ZL Mar25-May25 ZL Jul25-Aug25 0.094330 0.077282     August      NaN       NaN      NaN 0.056586 0.080930      NaN      NaN 0.094330        NaN      NaN       NaN       NaN
# ZL Mar25-May25 ZL Sep25-Mar26 0.133962 0.064591      March 0.042215  0.038905 0.133962 0.039170 0.062546 0.041400 0.047185 0.083194        NaN 0.055854  0.101475       NaN
# ZL May25-Jul25 ZL Dec25-Mar26 0.085567 0.070631       June      NaN       NaN      NaN      NaN      NaN 0.085567 0.055961 0.070364        NaN      NaN       NaN       NaN
# ZL May25-Jul25 ZL Sep25-Dec25 0.061650 0.060002       June      NaN       NaN      NaN      NaN      NaN 0.061650 0.059435 0.058922        NaN      NaN       NaN       NaN
# ZL May25-Jul25 ZL Jul25-Aug25 0.109462 0.072845     August      NaN       NaN      NaN      NaN 0.049610 0.059464      NaN 0.109462        NaN      NaN       NaN       NaN
# ZL May25-Jul25 ZL Sep25-Mar26 0.106428 0.058791      March      NaN  0.055189 0.106428 0.042281 0.040229 0.036491 0.050539 0.069217        NaN 0.069957       NaN       NaN
# ZL Dec25-Mar26 ZL Sep25-Mar26 0.078702 0.078702   November      NaN       NaN      NaN      NaN      NaN      NaN      NaN      NaN        NaN      NaN  0.078702       NaN
# ZL Sep25-Dec25 ZL Jul25-Aug25 0.048396 0.048396       June      NaN       NaN      NaN      NaN      NaN 0.048396      NaN      NaN        NaN      NaN       NaN       NaN
# ZL Jul25-Aug25 ZL Sep25-Mar26 0.072305 0.054272    October      NaN       NaN      NaN      NaN 0.055225 0.030268      NaN 0.061167   0.052393 0.072305       NaN       NaN

# %%
df = results
df = df.applymap(lambda x: round(x, 2) if isinstance(x, float) else x)

df.to_csv('/workspaces/Futures-First/BackTest/data/RatioResult/SoyOil_Zscore.csv',index=False)
# Out:
# /tmp/ipykernel_1605/1867335137.py:2: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: round(x, 2) if isinstance(x, float) else x)

# %%
import pandas as pd
import numpy as np
import os
from itertools import combinations
from datetime import datetime

def optimize_z_ratio_monthly(df):
    best_z = 0
    best_sharpe = -np.inf
    
    z_values = np.arange(0, 10.1, 0.1)
    
    for z in z_values:
        df['Spread'] = df['Value_X'] - z * df['Value_Y']
        returns = df['Spread'].pct_change().dropna()
        
        if len(returns) < 2 or returns.std() == 0:
            continue
        
        sharpe = returns.mean() / returns.std()
        if sharpe > best_sharpe:
            best_sharpe = sharpe
            best_z = z
            
    return best_z, best_sharpe

def process_contract_file(file_path):
    """Convert wide-format contract data to long format"""
    df = pd.read_csv(file_path)
    melted = pd.DataFrame()

    # Process each year's data columns
    for i in range(0, len(df.columns), 2):
        if i+1 >= len(df.columns):
            break
            
        date_col = df.columns[i]
        value_col = df.columns[i+1]
        year = value_col  # Get contract year from column name
        
        temp_df = df[[date_col, value_col]].copy()
        temp_df.columns = ['Date', 'Value']
        temp_df['ContractYear'] = year
        melted = pd.concat([melted, temp_df])

    melted['Date'] = pd.to_datetime(melted['Date'], errors='coerce')
    return melted.dropna(subset=['Date', 'Value'])

def process_files_monthly(directory):
    results = []
    
    for file1, file2 in combinations(os.listdir(directory), 2):
        if not (file1.endswith('.csv') and file2.endswith('.csv')):
            continue
            
        # Load and merge contract data
        df1 = process_contract_file(os.path.join(directory, file1))
        df2 = process_contract_file(os.path.join(directory, file2))
        
        merged = pd.merge(df1, df2, on='Date', suffixes=('_X', '_Y'))
        if merged.empty:
            continue
            
        # Extract month for grouping
        merged['Month'] = merged['Date'].dt.month
        
        monthly_z = []
        monthly_sharpe = []
        
        # Optimize for each month
        for month, group in merged.groupby('Month'):
            group = group.sort_values('Date')
            if len(group) < 5:  # Minimum data threshold
                continue
                
            z, sharpe = optimize_z_ratio_monthly(group)
            monthly_z.append(z)
            monthly_sharpe.append(sharpe)
        
        if monthly_z:
            results.append({
                'Contract Pair': f"{file1[:-4]}-{file2[:-4]}",
                'Best Monthly Z': np.mean(monthly_z),
                'Max Sharpe': np.max(monthly_sharpe),
                'Min Sharpe': np.min(monthly_sharpe),
                'Avg Sharpe': np.mean(monthly_sharpe)
            })
    
    return pd.DataFrame(results)

# Example usage
if __name__ == "__main__":
    results = process_files_monthly('/workspaces/Futures-First/BackTest/data/ZS Contracts')
    print("Monthly Optimization Results:")
    print(results.sort_values('Avg Sharpe', ascending=False).to_string(index=False))
# Out:
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# ...
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.local/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/codespace/.python/current/lib/python3.12/site-packages/numpy/_core/_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 93
#      91 # Example usage
#      92 if __name__ == "__main__":
# ---> 93     results = process_files_monthly('/workspaces/Futures-First/BackTest/data/ZS Contracts')
#      94     print("Monthly Optimization Results:")
#      95     print(results.sort_values('Avg Sharpe', ascending=False).to_string(index=False))
#
# Cell In[16], line 76, in process_files_monthly(directory)
#      73 if len(group) < 5:  # Minimum data threshold
#      74     continue
# ---> 76 z, sharpe = optimize_z_ratio_monthly(group)
#      77 monthly_z.append(z)
#      78 monthly_sharpe.append(sharpe)
#
# Cell In[16], line 14, in optimize_z_ratio_monthly(df)
#      11 z_values = np.arange(0, 10.1, 0.1)
#      13 for z in z_values:
# ---> 14     df['Spread'] = df['Value_X'] - z * df['Value_Y']
#      15     returns = df['Spread'].pct_change().dropna()
#      17     if len(returns) < 2 or returns.std() == 0:
#
# File ~/.local/lib/python3.12/site-packages/pandas/core/frame.py:4075, in DataFrame.__getitem__(self, key)
#    4070 is_mi = isinstance(self.columns, MultiIndex)
#    4071 # GH#45316 Return view if key is not duplicated
#    4072 # Only use drop_duplicates with duplicates for performance
#    4073 if not is_mi and (
#    4074     self.columns.is_unique
# -> 4075     and key in self.columns
#    4076     or key in self.columns.drop_duplicates(keep=False)
#    4077 ):
#    4078     return self._get_item_cache(key)
#    4080 elif is_mi and self.columns.is_unique and key in self.columns:
#
# File ~/.local/lib/python3.12/site-packages/pandas/core/indexes/base.py:5323, in Index.__contains__(self, key)
#    5318     """
#    5319     Return a boolean if we need a qualified .info display.
#    5320     """
#    5321     return is_object_dtype(self.dtype)
# -> 5323 def __contains__(self, key: Any) -> bool:
#    5324     """
#    5325     Return a boolean indicating whether the provided key is in the index.
#    5326
#    (...)
#    5356     False
#    5357     """
#    5358     hash(key)
#
# KeyboardInterrupt:

# %%
import pandas as pd
import numpy as np
import os
from itertools import combinations

def optimize_z_ratio(df):
    best_z = None
    best_sharpe = -float('inf')
    
    z_values = np.arange(0, 10.1, 0.1)
    
    for z in z_values:
        df['Z'] = df['X'] - (z * df['Y'])
        
        # Calculate returns
        df['Returns'] = df['Z'].pct_change()
        
        # Remove NaN and infinite values
        df['Returns'] = df['Returns'].replace([np.inf, -np.inf], np.nan).dropna()
        
        # Skip if no valid returns exist
        if df['Returns'].empty or df['Returns'].std() == 0:
            continue
        
        # Calculate Sharpe ratio (assuming risk-free rate = 0)
        sharpe_ratio = df['Returns'].mean() / df['Returns'].std()
        
        if sharpe_ratio > best_sharpe:
            best_sharpe = sharpe_ratio
            best_z = z
    
    return best_z if best_z is not None else 0, best_sharpe

def process_files_in_directory(directory, window_size=230):
    files = [f for f in os.listdir(directory) if f.endswith('.csv')]
    results_list = []
    
    for file1, file2 in combinations(files, 2):
        df1 = pd.read_csv(os.path.join(directory, file1))
        df2 = pd.read_csv(os.path.join(directory, file2))

        df1 = df1.iloc[:, 1::2]  # Select every second column starting from index 1
        df2 = df2.iloc[:, 1::2]  # Select every second column starting from index 1

        optimization_results = []

        for i in range(df1.columns.size):
            df3 = pd.DataFrame()
            df3['X'] = pd.to_numeric(df1.iloc[:, i], errors='coerce')
            df3['Y'] = pd.to_numeric(df2.iloc[:, i], errors='coerce')

            # Drop NaN values
            df3 = df3.dropna(subset=['X', 'Y'])

            # Use last 250 rows, then apply window size
            df3 = df3[-250:].iloc[:window_size]

            # Skip empty dataframes
            if df3.empty:
                continue

            z, sharpe = optimize_z_ratio(df3)
            optimization_results.append(z)

        # Remove None values
        optimization_results = [z for z in optimization_results if z is not None]

        if optimization_results:
            mean_z = np.mean(optimization_results)
            median_z = np.median(optimization_results)
        else:
            mean_z, median_z = 0, 0

        results_list.append({
            'Contract 1': file1,
            'Contract 2': file2,
            'Mean': mean_z,
            'Median': median_z,
            'Sharpe Ratio': sharpe
        })

    return pd.DataFrame(results_list)

# Specify the directory containing the CSV files
directory = '/workspaces/Futures-First/BackTest/data/ZS Contracts'

# Process all files in the directory and get the results DataFrame
results_df = process_files_in_directory(directory, window_size=230)

# Display the results DataFrame
print(results_df)

# %%
results_df.to_csv('/workspaces/Futures-First/BackTest/data/RatioResult/ZS1-Test.csv',index=False)

# %%
# Monthly
import pandas as pd
import numpy as np
import os
from itertools import combinations
from datetime import datetime

def optimize_z_ratio_monthly(df_month):
    best_z = None
    best_sharpe = -float('inf')
    
    z_values = np.arange(0, 10.1, 0.1)
    
    for z in z_values:
        df_month['Z'] = df_month['Spread_X'] - (z * df_month['Spread_Y'])  # Assuming spread columns are named 'Spread_X' and 'Spread_Y'
        
        # Calculate daily returns of the spread
        df_month['Returns'] = df_month['Z'].pct_change().dropna()
        
        # Skip if no returns or zero volatility
        if df_month['Returns'].empty or df_month['Returns'].std() == 0:
            continue
        
        # Sharpe ratio (annualized)
        sharpe_ratio = df_month['Returns'].mean() / df_month['Returns'].std() * np.sqrt(252)  # 252 trading days
        
        if sharpe_ratio > best_sharpe:
            best_sharpe = sharpe_ratio
            best_z = z
    
    return best_z if best_z is not None else np.nan, best_sharpe

def process_monthly_spreads(directory):
    files = [f for f in os.listdir(directory) if f.endswith('.csv')]
    results_list = []
    
    for file1, file2 in combinations(files, 2):
        # Load spread data for both contracts
        df1 = pd.read_csv(os.path.join(directory, file1), parse_dates=['Date'], index_col='Date')
        df2 = pd.read_csv(os.path.join(directory, file2), parse_dates=['Date'], index_col='Date')
        
        # Align dates and keep only common trading days
        common_dates = df1.index.intersection(df2.index)
        df1 = df1.loc[common_dates]
        df2 = df2.loc[common_dates]
        
        # Resample data by month
        monthly_groups = df1.groupby(pd.Grouper(freq='M'))
        
        for month, df1_month in monthly_groups:
            # Skip months with insufficient data (e.g., < 15 trading days)
            if len(df1_month) < 15:
                continue
            
            # Get corresponding month data for df2
            df2_month = df2.loc[month.strftime('%Y-%m')]
            
            # Create a DataFrame for the month's spreads
            df_month = pd.DataFrame({
                'Spread_X': df1_month['Spread'],  # Replace 'Spread' with your actual column name
                'Spread_Y': df2_month['Spread']
            }).dropna()
            
            # Skip if no data after alignment
            if df_month.empty:
                continue
            
            # Optimize Z ratio for the month
            best_z, sharpe = optimize_z_ratio_monthly(df_month)
            
            # Append results
            results_list.append({
                'Contract 1': file1,
                'Contract 2': file2,
                'Month': month.strftime('%Y-%m'),
                'Best_Z': best_z,
                'Sharpe': sharpe
            })
    
    results_df = pd.DataFrame(results_list)
    
    # Aggregate results by month (mean/median of Best_Z across pairs)
    monthly_summary = results_df.groupby('Month').agg({
        'Best_Z': ['mean', 'median'],
        'Sharpe': 'mean'
    }).reset_index()
    
    return monthly_summary, results_df

# Directory containing spread CSV files
directory = '/workspaces/Futures-First/BackTest/data/ZM Contracts'

# Process files and get results
monthly_summary, detailed_results = process_monthly_spreads(directory)

# Display results
print("Monthly Summary:")
print(monthly_summary)
print("\nDetailed Results:")
print(detailed_results)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 94
#      91 directory = '/workspaces/Futures-First/BackTest/data/ZM Contracts'
#      93 # Process files and get results
# ---> 94 monthly_summary, detailed_results = process_monthly_spreads(directory)
#      96 # Display results
#      97 print("Monthly Summary:")
#
# Cell In[6], line 39, in process_monthly_spreads(directory)
#      35 results_list = []
#      37 for file1, file2 in combinations(files, 2):
#      38     # Load spread data for both contracts
# ---> 39     df1 = pd.read_csv(os.path.join(directory, file1), parse_dates=['Date'], index_col='Date')
#      40     df2 = pd.read_csv(os.path.join(directory, file2), parse_dates=['Date'], index_col='Date')
#      42     # Align dates and keep only common trading days
#
# File ~/.local/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~/.local/lib/python3.12/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~/.local/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~/.local/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1898, in TextFileReader._make_engine(self, f, engine)
#    1895     raise ValueError(msg)
#    1897 try:
# -> 1898     return mapping[engine](f, **self.options)
#    1899 except Exception:
#    1900     if self.handles is not None:
#
# File ~/.local/lib/python3.12/site-packages/pandas/io/parsers/c_parser_wrapper.py:161, in CParserWrapper.__init__(self, src, **kwds)
#     155         self._validate_usecols_names(
#     156             usecols,
#     157             self.names,  # type: ignore[has-type]
#     158         )
#     160 # error: Cannot determine type of 'names'
# --> 161 self._validate_parse_dates_presence(self.names)  # type: ignore[has-type]
#     162 self._set_noconvert_columns()
#     164 # error: Cannot determine type of 'names'
#
# File ~/.local/lib/python3.12/site-packages/pandas/io/parsers/base_parser.py:243, in ParserBase._validate_parse_dates_presence(self, columns)
#     233 missing_cols = ", ".join(
#     234     sorted(
#     235         {
#    (...)
#     240     )
#     241 )
#     242 if missing_cols:
# --> 243     raise ValueError(
#     244         f"Missing column provided to 'parse_dates': '{missing_cols}'"
#     245     )
#     246 # Convert positions to actual column names
#     247 return [
#     248     col if (isinstance(col, str) or col in columns) else columns[col]
#     249     for col in cols_needed
#     250 ]
#
# ValueError: Missing column provided to 'parse_dates': 'Date'

# %%
# Manual Change

import pandas as pd
import numpy as np

def optimize_z_ratio(df):
    
    # Initialize tracking variables
    best_z = None
    lowest_variance = float('inf')
    lowest_standard_deviation = float('inf')
    
    # Iterate through potential z values with decimal precision
    # Using a range from 0 to 10 with 0.1 increments
    z_values = np.arange(0, 10.1, 0.1)
    
    results = []
    
    for z in z_values:
        # Calculate Z column
        df['Z'] = df['X'] - (z * df['Y'])
        
        # Calculate variance and standard deviation of Z
        z_variance = df['Z'].var()
        z_std = df['Z'].std()
        
        # Track results
        results.append({
            'z': z,
            'variance': z_variance,
            'standard_deviation': z_std
        })
        
        # Update best z if current z has lower variance
        if z_variance < lowest_variance:
            lowest_variance = z_variance
            best_z = z
            lowest_standard_deviation = z_std
    
    # Convert results to DataFrame for easy analysis
    results_df = pd.DataFrame(results)
    
    # Return optimization results
    return best_z
    # return {
    #     'best_z': best_z,
    #     'lowest_variance': lowest_variance,
    #     'lowest_standard_deviation': lowest_standard_deviation,
    #     'results_dataframe': results_df
    # }

optimization_results = []

# df = pd.read_csv('/workspaces/Futures-First/BackTest/data/data.csv', names=['X', 'Y'])
df1 = pd.read_csv('/workspaces/Futures-First/BackTest/data/ZC Contracts/ZC Dec25-Jul26.csv')
df2 = pd.read_csv('/workspaces/Futures-First/BackTest/data/ZC Contracts/ZC Mar26-May26.csv')

df1 = df1.iloc[:, 1::2]
df2 = df2.iloc[:, 1::2]
# df1 = df1.iloc[:,1:]
# df2 = df2.iloc[:,1:]

for i in range(df1.columns.size):
    df3 = pd.DataFrame()
    df3['X'] = pd.to_numeric(df1.iloc[:,i], errors='coerce')
    df3['Y'] = pd.to_numeric(df2.iloc[:,i], errors='coerce')

    # Remove rows with NaN values
    df3 = df3.dropna()
    df3 = df3[-250:]
    df3 = df3[:230]

    # Perform optimization
    # optimization_results = optimize_z_ratio(df)
    optimization_results.append(optimize_z_ratio(df3))

# Print results
# print("Optimization Results:")
# print(f"Best Z Value: {optimization_results['best_z']:.1f}")
# print(f"Lowest Variance: {optimization_results['lowest_variance']:.4f}")
# print(f"Lowest Standard Deviation: {optimization_results['lowest_standard_deviation']:.4f}")

# Optional: Display full results DataFrame for detailed analysis
# print("\nDetailed Z Value Analysis:")
# print(optimization_results['results_dataframe'])

# print(optimization_results)
optimization_results_series = pd.Series(optimization_results)

# Calculate mean and median
mean_z = optimization_results_series.mean()
median_z = optimization_results_series.median()

print(f"Mean of optimization results: {mean_z}")
print(f"Median of optimization results: {median_z}")
# Out:
# Mean of optimization results: 0.925
# Median of optimization results: 0.9

# %%
# import pandas as pd
# import numpy as np
# from statsmodels.tsa.stattools import adfuller

# # Function to calculate correlation between X and Y
# def calculate_correlation(df):
#     return df['X'].corr(df['Y'])

# # Function to check mean reversion using ADF test
# def test_mean_reversion(df):
#     result = adfuller(df['Z'])
#     p_value = result[1]
#     return p_value < 0.05  # Mean-reverting if p-value < 0.05

# # Function to incorporate seasonality check
# def seasonality_check(df, seasonal_avg):
#     recent_avg = df['X'].mean()
#     return abs(recent_avg - seasonal_avg) < 0.05 * seasonal_avg  # Within 5% deviation

# # Function for dynamic optimization with rolling windows
# def dynamic_optimize_z_ratio(df, window_size):
#     rolling_results = []

#     for start in range(0, len(df) - window_size + 1):
#         # Slice rolling window
#         rolling_df = df.iloc[start:start + window_size]
#         best_z = optimize_z_ratio(rolling_df)
#         rolling_results.append(best_z)

#     return rolling_results

# # Function to optimize Z ratio
# # Reuses the original implementation

# def optimize_z_ratio(df):
#     best_z = None
#     lowest_variance = float('inf')

#     z_values = np.arange(0, 10.1, 0.1)
#     for z in z_values:
#         df['Z'] = df['X'] - (z * df['Y'])
#         z_variance = df['Z'].var()
#         if z_variance < lowest_variance:
#             lowest_variance = z_variance
#             best_z = z

#     return best_z

# # Main Code
# df1 = pd.read_csv('/workspaces/Futures-First/BackTest/data/ZS Spreads/ZS Jul25-Aug25.csv')
# df2 = pd.read_csv('/workspaces/Futures-First/BackTest/data/ZS Spreads/ZS Jul25-Aug25.csv')
# df1 = df1.iloc[:, 1::2]
# df2 = df2.iloc[:, 1::2]

# seasonal_avg = 100  # Placeholder for seasonal average, replace with actual historical data
# window_size = 250  # Rolling window size
# optimization_results = []

# for i in range(df1.columns.size):
#     df3 = pd.DataFrame()
#     df3['X'] = pd.to_numeric(df1.iloc[:, i], errors='coerce')
#     df3['Y'] = pd.to_numeric(df2.iloc[:, i], errors='coerce')
#     df3 = df3.dropna()[-250:][:230]

#     # Correlation Check
#     correlation = calculate_correlation(df3)
#     if abs(correlation) < 0.5:  # Filter weak correlations
#         print(f"Skipping column pair {i} due to low correlation ({correlation:.2f})")
#         continue

#     # Seasonality Check
#     if not seasonality_check(df3, seasonal_avg):
#         print(f"Skipping column pair {i} due to seasonal mismatch")
#         continue

#     # Perform Optimization
#     dynamic_results = dynamic_optimize_z_ratio(df3, window_size)
#     mean_z = np.mean(dynamic_results)

#     # Test Mean Reversion
#     df3['Z'] = df3['X'] - (mean_z * df3['Y'])
#     if not test_mean_reversion(df3):
#         print(f"Skipping column pair {i} as Z is not mean-reverting")
#         continue

#     # Store result
#     optimization_results.append(mean_z)

# # Calculate and print overall statistics
# optimization_results_series = pd.Series(optimization_results)
# mean_z = optimization_results_series.mean()
# median_z = optimization_results_series.median()

# print(f"Mean of optimization results: {mean_z}")
# print(f"Median of optimization results: {median_z}")
# Out:
# Skipping column pair 0 due to seasonal mismatch
# Skipping column pair 1 due to seasonal mismatch
# Skipping column pair 2 due to seasonal mismatch
# Skipping column pair 3 due to seasonal mismatch
# Skipping column pair 4 due to seasonal mismatch
# Skipping column pair 5 due to seasonal mismatch
# Skipping column pair 6 due to seasonal mismatch
# Skipping column pair 7 due to seasonal mismatch
# Skipping column pair 8 due to seasonal mismatch
# Skipping column pair 9 due to seasonal mismatch
# Skipping column pair 10 due to seasonal mismatch
# Skipping column pair 11 due to seasonal mismatch
# Skipping column pair 12 due to seasonal mismatch
# Skipping column pair 13 due to seasonal mismatch
# Skipping column pair 14 due to seasonal mismatch
# Skipping column pair 15 due to seasonal mismatch
# Skipping column pair 16 due to seasonal mismatch
# Skipping column pair 17 due to seasonal mismatch
# Skipping column pair 18 due to seasonal mismatch
# Skipping column pair 19 due to seasonal mismatch
# Mean of optimization results: nan
# Median of optimization results: nan

# %%
import pandas as pd

df1 = pd.read_csv('/workspaces/Futures-First/BackTest/data/Data1.csv')
df2 = pd.read_csv('/workspaces/Futures-First/BackTest/data/Data2.csv')
df1 = df1.iloc[:, 1::2]
df2 = df2.iloc[:, 1::2]
# Out:
#      2025   2024   2023    2022   2021   2020  2019  2018   2017   2016  \
# 0     NaN  21.50  48.75    2.25  10.00    NaN   NaN  5.50  10.25  13.00
# 1     NaN    NaN  48.75    2.25  10.00  15.25   NaN   NaN  10.25  12.25
# 2     NaN    NaN    NaN    2.25  10.00  15.25  5.50   NaN  10.25  12.25
# 3     NaN  21.50    NaN     NaN  10.00  16.00  5.50  5.50    NaN  12.25
# 4     NaN  21.50  48.75     NaN  10.00  16.00  5.00  5.50    NaN    NaN
# ..    ...    ...    ...     ...    ...    ...   ...   ...    ...    ...
# 743   NaN    NaN  60.00  179.75  99.25   6.50   NaN -4.75  -3.25  18.50
# 744   NaN    NaN  64.00  189.25  58.50   7.50   NaN   NaN  -2.75  20.50
# 745   NaN  40.75    NaN  134.25  54.50  10.00 -5.25   NaN    NaN   4.25
# 746   NaN  41.75    NaN     NaN  51.25  11.00 -4.25 -3.75    NaN    NaN
# 747   NaN  27.50  38.00     NaN    NaN   6.50 -4.50 -3.75  -7.25    NaN
#
#       2015    2014
# 0    15.25     NaN
# 1    15.25    9.75
# 2    15.25    9.75
# 3    15.25    9.75
# 4    15.25    9.75
# ..     ...     ...
# 743  36.50     NaN
# 744  33.00  206.25
# 745  32.50  195.75
# 746  56.75  185.00
# 747  53.25  126.25
#
# [748 rows x 12 columns]

# %%
# import pandas as pd
# import numpy as np

# def optimize_z_ratio(df):
#     """
#     Optimize the z ratio to minimize risk in a futures trading structure.
    
#     Parameters:
#     df (pandas.DataFrame): DataFrame with 'X' and 'Y' price columns
    
#     Returns:
#     dict: Optimization results including best z value and associated metrics
#     """
#     # Initialize tracking variables
#     best_z = None
#     lowest_variance = float('inf')
#     lowest_standard_deviation = float('inf')
    
#     # Iterate through potential z values with decimal precision
#     # Using a range from 0 to 10 with 0.1 increments
#     z_values = np.arange(0, 10.1, 0.1)
    
#     results = []
    
#     for z in z_values:
#         # Calculate Z column
#         df['Z'] = df['X'] - (z * df['Y'])
        
#         # Calculate variance and standard deviation of Z
#         z_variance = df['Z'].var()
#         z_std = df['Z'].std()
        
#         # Track results
#         results.append({
#             'z': z,
#             'variance': z_variance,
#             'standard_deviation': z_std
#         })
        
#         # Update best z if current z has lower variance
#         if z_variance < lowest_variance:
#             lowest_variance = z_variance
#             best_z = z
#             lowest_standard_deviation = z_std
    
#     # Convert results to DataFrame for easy analysis
#     results_df = pd.DataFrame(results)
    
#     # Return optimization results
#     return {
#         'best_z': best_z,
#         'lowest_variance': lowest_variance,
#         'lowest_standard_deviation': lowest_standard_deviation,
#         'results_dataframe': results_df
#     }

# # Read the data
# df = pd.read_csv('/workspaces/Futures-First/BackTest/data/data.csv', names=['X', 'Y'])
# # Convert to numeric, replacing 'NA' and empty strings with NaN
# df['X'] = pd.to_numeric(df['X'], errors='coerce')
# df['Y'] = pd.to_numeric(df['Y'], errors='coerce')

# # Remove rows with NaN values
# df = df.dropna()
# df = df[-150:]

# # Perform optimization
# optimization_results = optimize_z_ratio(df)

# # Print results
# print("Optimization Results:")
# print(f"Best Z Value: {optimization_results['best_z']:.1f}")
# print(f"Lowest Variance: {optimization_results['lowest_variance']:.4f}")
# print(f"Lowest Standard Deviation: {optimization_results['lowest_standard_deviation']:.4f}")

# # Optional: Display full results DataFrame for detailed analysis
# print("\nDetailed Z Value Analysis:")
# print(optimization_results['results_dataframe'])
# Out:
# Optimization Results:
# Best Z Value: 2.2
# Lowest Variance: 1.8206
# Lowest Standard Deviation: 1.3493
#
# Detailed Z Value Analysis:
#         z     variance  standard_deviation
# 0     0.0   158.779276           12.600765
# 1     0.1   145.051513           12.043733
# 2     0.2   131.951681           11.487022
# 3     0.3   119.479780           10.930681
# 4     0.4   107.635810           10.374768
# ..    ...          ...                 ...
# 96    9.6  1704.280065           41.282927
# 97    9.7  1750.833692           41.842965
# 98    9.8  1798.015251           42.403010
# 99    9.9  1845.824741           42.963063
# 100  10.0  1894.262162           43.523122
#
# [101 rows x 3 columns]
